# %% [markdown]
# Date: 2024-12-11
#
# Latest change when and what:
#
# Notes:
#
# # Baseline models: Bag og Words and tf-idf
#
# Trying different baseline models and comparing their outcomes. Please note - all the models were first run using the training and the validation datasets. When the parameters of the models had been chosen, we then finally tested on the test dataset, too. So, the test dataset was only used once.

# %%
# importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_extraction.text import CountVectorizer, TfidVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import f1_score, classification_report, roc_auc_score, roc_curve, average_precision_score, make_scorer, accuracy_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split

import pickle as pkl
from sklearn.datasets import make_classification
from wordcloud import WordCloud
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 7
#       4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
# ----> 7 from sklearn.feature_extraction.text import CountVectorizer, TfidVectorizer
#       8 from sklearn.linear_model import LogisticRegression
#       9 from sklearn.ensemble import RandomForestClassifier
#
# ImportError: cannot import name 'TfidVectorizer' from 'sklearn.feature_extraction.text' (/home/ucloud/.local/lib/python3.12/site-packages/sklearn/feature_extraction/text.py)

# %%
# loading train, test and validation datasets - lowercase!
train_data = pd.read_csv("../2_preprocessing/train_lowercase.csv")
test_data = pd.read_csv("../2_preprocessing/test_lowercase.csv")
val_data = pd.read_csv('../2_preprocessing/validation_lowercase.csv')

# %%
# checking average number of characters in scripts - just to get info
average_characters = train_data['script'].apply(len).mean()
average_characters = round(average_characters,0)

print(f"Average number of characters: {average_characters}")
# Out:
# Average number of characters: 124366.0

# %% [markdown]
# ## Bag of Words (BoW)

# %% [markdown]
# .fit_transform uses the input to create the frequency matrix of words.
# .transform counts the words in the input using the frequency matrix already created with the training data
# so if a word is not present in the frequency matrix created with the training data, it is lost

# %%
# creating frequency matrix using the training data and transforming the validation and the test dataset
# train data 
texts_train = train_data["script"].to_list()
y_train = train_data.passed_bechdel.to_list()

# create frequency matrix of words
vectorizer = CountVectorizer()
features_train = vectorizer.fit_transform(texts_train) # only for training!

# validation data 
texts_val = val_data["script"].to_list()
y_val = val_data.passed_bechdel.to_list()

# plot the words in the validation dataset in the matrix made on the training data 
features_val = vectorizer.transform(texts_val) # notice - only transform, not fitting

# test data 
texts_test = test_data["script"].to_list()
y_test = test_data.passed_bechdel.to_list()

# plot the words in the test dataset in the matrix made on the training data 
features_test = vectorizer.transform(texts_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # creating frequency matrix using the training data and transforming the validation and the test dataset
#       2 # train data
# ----> 3 texts_train = train_data["script"].to_list()
#       4 y_train = train_data.passed_bechdel.to_list()
#       6 # create frequency matrix of words
#
# NameError: name 'train_data' is not defined

# %%
# sanity check
print(features_train.shape)
print(len(vectorizer.vocabulary_))
vectorizer.vocabulary_
# Out:
# (1418, 339126)
# 339126
# {'alice': 24707,
#  'by': 57022,
#  'linda': 179313,
#  'woolverton': 331083,
#  'based': 41067,
#  'on': 215199,
#  'alices': 24717,
#  'adventures': 21218,
#  'in': 155352,
#  'wonderland': 330728,
#  'through': 299850,
#  'the': 296163,
#  'looking': 181877,
#  'glass': 129786,
#  'lewis': 177850,
#  'carroll': 60852,
#  '9908': 16306,
#  'white': 327154,
#  'shooting': 267457,
#  'script': 260843,
#  '102808': 1088,
#  'blue': 48766,
#  'revised': 249266,
#  'pages': 221513,
#  'fade': 111324,
#  'ext': 109990,
#  'london': 181445,
#  '1855': 5003,
#  'night': 207163,
#  'warm': 322703,
#  'light': 178648,
#  'shines': 266736,
#  'from': 122918,
#  'study': 285868,
#  'of': 212872,
#  'gracious': 132809,
#  'kingsley': 170421,
#  'home': 147723,
#  'man': 186254,
#  'silhouetted': 269586,
#  'window': 328945,
#  'speaks': 277925,
#  'with': 329731,
#  'ardor': 31950,
#  'int': 158081,
#  'cont': 74527,
#  'charles': 64479,
#  'has': 140640,
#  'just': 167187,
#  'described': 87760,
#  'his': 146397,
#  'new': 206267,
#  'venture': 317957,
#  'to': 302274,
#  'friends': 122609,
#  'including': 155736,
#  'lord': 182188,
#  'ascot': 33652,
#  'you': 335714,
#  'have': 141050,
#  'finally': 115882,
#  'lost': 182364,
#  'your': 336187,
#  'senses': 263515,
#  'colleague': 71265,
#  'this': 298525,
#  'is': 160133,
#  'impossible': 155093,
#  'for': 119875,
#  'some': 275555,
#  'gentlemen': 127490,
#  'only': 215955,
#  'way': 323775,
#  'achieve': 19905,
#  'believe': 44034,
#  'it': 160917,
#  'possible': 233519,
#  'that': 295772,
#  'kind': 170294,
#  'thinking': 298245,
#  'could': 77104,
#  'ruin': 254708,
#  'im': 154265,
#  'willing': 328648,
#  'take': 291334,
#  'chance': 64091,
#  'imagine': 154339,
#  'trading': 305208,
#  'posts': 233728,
#  'rangoon': 242686,
#  'bangkok': 40049,
#  'jakarta': 162601,
#  'he': 141524,
#  'stops': 284178,
#  'nine': 207629,
#  'yearold': 334383,
#  'daughter': 83836,
#  'stands': 281558,
#  'at': 34777,
#  'door': 94285,
#  'her': 143667,
#  'nightgown': 207266,
#  'clearly': 68628,
#  'frightened': 122697,
#  'goes': 130982,
#  'contd': 74606,
#  'nightmare': 207327,
#  'again': 22047,
#  'she': 265831,
#  'nods': 208451,
#  'takes': 291384,
#  'hand': 139028,
#  'and': 27704,
#  'turns': 308867,
#  'guests': 135576,
#  'wont': 330795,
#  'be': 42190,
#  'long': 181484,
#  'young': 336095,
#  'bedroom': 43089,
#  'later': 174944,
#  'sits': 270662,
#  'bed': 42942,
#  'listening': 179881,
#  'utmost': 316132,
#  'seriousness': 264036,
#  'falling': 111732,
#  'down': 95300,
#  'dark': 83337,
#  'hole': 147411,
#  'then': 296893,
#  'see': 262094,
#  'strange': 284654,
#  'creatures': 78842,
#  'what': 326143,
#  'continued': 74894,
#  'well': 324873,
#  'theres': 297308,
#  'dodo': 93157,
#  'bird': 46834,
#  'rabbit': 241397,
#  'waistcoat': 321615,
#  'smiling': 273444,
#  'cat': 61476,
#  'didnt': 89322,
#  'know': 171515,
#  'cats': 61795,
#  'smile': 273388,
#  'neither': 205567,
#  'did': 89245,
#  'oh': 213748,
#  'caterpillar': 61652,
#  'hmm': 146858,
#  'do': 92689,
#  'think': 298213,
#  'ive': 161796,
#  'gone': 131494,
#  'round': 253824,
#  'bend': 44442,
#  'feels': 113528,
#  'forehead': 120083,
#  'as': 33506,
#  'if': 153223,
#  'fever': 114410,
#  'afraid': 21793,
#  'so': 274610,
#  'youre': 336212,
#  'mad': 184889,
#  'bonkers': 50186,
#  'off': 212966,
#  'head': 141553,
#  'but': 56370,
#  'i1l': 151966,
#  'tell': 294091,
#  'secretall': 261877,
#  'best': 45177,
#  'people': 226055,
#  'are': 31964,
#  'smiles': 273407,
#  'leans': 176038,
#  'against': 22135,
#  'him': 145783,
#  'its': 161426,
#  'dream': 96073,
#  'nothing': 209979,
#  'can': 59014,
#  'harm': 140331,
#  'there': 297202,
#  'get': 128037,
#  'too': 303455,
#  'always': 26409,
#  'wake': 321808,
#  'up': 314852,
#  'like': 178914,
#  'pinches': 229142,
#  'screams': 260569,
#  'back': 38369,
#  'cut': 81392,
#  'outskirts': 219316,
#  'ten': 294311,
#  'years': 334389,
#  'horsedrawn': 148786,
#  'carriage': 60784,
#  'careens': 60242,
#  'road': 251393,
#  'full': 123834,
#  'gallop': 125347,
#  'day': 84090,
#  'verge': 318081,
#  'womanhood': 330559,
#  'beautiful': 42624,
#  'slightly': 272404,
#  'offkilter': 213311,
#  'sees': 262340,
#  'world': 331483,
#  'different': 89553,
#  'eyes': 110580,
#  'than': 295641,
#  'other': 218362,
#  'age': 22232,
#  'presently': 235483,
#  'shes': 266359,
#  'tired': 301632,
#  'grumpy': 135044,
#  'mother': 200153,
#  'fusses': 124492,
#  'wild': 328432,
#  'mane': 186468,
#  'blonde': 48368,
#  'hair': 137464,
#  'must': 202649,
#  'we': 324002,
#  'go': 130523,
#  'doubt': 95094,
#  'they1ll': 297741,
#  'notice': 210051,
#  'never': 206182,
#  'arrive': 33117,
#  'helen': 142875,
#  'they': 297732,
#  'will': 328576,
#  'reties': 248744,
#  'waist': 321608,
#  'sash': 257838,
#  'feeling': 113501,
#  'corset': 76673,
#  'wheres': 326715,
#  'pulls': 238560,
#  'dress': 96241,
#  'bare': 40465,
#  'legs': 176735,
#  'no': 208209,
#  'stockings': 283831,
#  'them': 296658,
#  'not': 209827,
#  'properly': 237160,
#  'dressed': 96250,
#  'whos': 327763,
#  'say': 258390,
#  'proper': 237156,
#  'was': 322911,
#  'agreed': 22608,
#  'wearing': 324163,
#  'codfish': 70680,
#  'would': 331812,
#  'wear': 324137,
#  'me': 190078,
#  'please': 230861,
#  'today': 302501,
#  'frustrated': 123342,
#  'looks': 181928,
#  'out': 218820,
#  'mutters': 202818,
#  'father': 112682,
#  'laughed': 175208,
#  'hurt': 151232,
#  'mothers': 200234,
#  'face': 111019,
#  'instantly': 157878,
#  'regrets': 246160,
#  'words': 331234,
#  'sorry': 276613,
#  'sleep': 272174,
#  'last': 174816,
#  'pats': 224279,
#  'forgiving': 120289,
#  'gesture': 128015,
#  'bad': 38846,
#  'dreams': 96109,
#  'one': 215408,
#  'same': 256927,
#  'ever': 108129,
#  'since': 269994,
#  'remember': 246879,
#  'thats': 295972,
#  'normal': 209515,
#  'dont': 94045,
#  'most': 200055,
#  'removes': 247057,
#  'own': 220347,
#  'jewelry': 164056,
#  'puts': 239331,
#  'now': 210400,
#  'manage': 186280,
#  'estate': 107136,
#  'gardens': 125898,
#  'garden': 125872,
#  'party': 223551,
#  'swing': 289739,
#  'everyone': 108336,
#  'turned': 308811,
#  'their': 296563,
#  'summer': 287431,
#  'finery': 116058,
#  'play': 230670,
#  'croquet': 79611,
#  'great': 133586,
#  'lawn': 175556,
#  'skiffs': 271333,
#  'drift': 96361,
#  'lazily': 175725,
#  'meandering': 190192,
#  'river': 251093,
#  'approaches': 31256,
#  'lady': 173619,
#  'fixed': 117200,
#  'unnatural': 313774,
#  'stately': 282059,
#  'aristocratic': 32418,
#  'redfaced': 245312,
#  'annoyance': 29146,
#  'thought': 299160,
#  'youd': 335852,
#  'hamish': 138883,
#  'waiting': 321680,
#  'dance': 82879,
#  'pushes': 239168,
#  'realize': 244121,
#  'past': 223901,
#  'four': 120974,
#  'everything': 108374,
#  'rushed': 255093,
#  'am': 26453,
#  'mind': 194418,
#  'rushes': 255099,
#  'forgive': 120282,
#  'my': 202932,
#  'wife': 328250,
#  'been': 43339,
#  'planning': 230380,
#  'affair': 21594,
#  'twenty': 309346,
#  'were': 325477,
#  'here': 143776,
#  'condolences': 73410,
#  'madame': 184902,
#  'husband': 151274,
#  'often': 213591,
#  'truly': 307595,
#  'vision': 319715,
#  'thank': 295660,
#  'hope': 148452,
#  'taken': 291364,
#  'advantage': 21198,
#  'misfortune': 195358,
#  'course': 77508,
#  'pleased': 230876,
#  'youve': 336564,
#  'purchased': 238928,
#  'company': 72519,
#  'fool': 119644,
#  'investing': 159302,
#  'when': 326618,
#  'had': 137118,
#  'quadrille': 240131,
#  'does': 93211,
#  'line': 179360,
#  'who': 327416,
#  'after': 21872,
#  'refined': 245810,
#  'immaculate': 154599,
#  'arrogance': 33153,
#  'tire': 301630,
#  'contrary': 75172,
#  'find': 115943,
#  'invigorating': 159333,
#  'struts': 285656,
#  'peacock': 224936,
#  'laughs': 175243,
#  'amuse': 27359,
#  'sudden': 286865,
#  'all': 25325,
#  'ladies': 173563,
#  'top': 303722,
#  'hats': 140942,
#  'men': 191544,
#  'bonnets': 50206,
#  'doesnt': 93231,
#  'even': 108027,
#  'crack': 78229,
#  'keep': 168897,
#  'visions': 319725,
#  'yourself': 336319,
#  'remain': 246785,
#  'silent': 269550,
#  'fades': 111334,
#  'without': 329847,
#  'whole': 327526,
#  'flock': 118320,
#  'geese': 126973,
#  'overhead': 219769,
#  'distracted': 92087,
#  'bumps': 55549,
#  'into': 158901,
#  'dancers': 82907,
#  'front': 123058,
#  'pardon': 222955,
#  'us': 315688,
#  'miss': 195469,
#  'where': 326677,
#  'wondering': 330710,
#  'fly': 118888,
#  'why': 327893,
#  'waste': 323176,
#  'time': 301031,
#  'about': 19010,
#  'such': 286773,
#  'an': 27421,
#  'thing': 298063,
#  'wouldnt': 331844,
#  'said': 256309,
#  'sometimes': 275840,
#  'believed': 44035,
#  'six': 270788,
#  'things': 298122,
#  'before': 43557,
#  'breakfast': 52581,
#  'memory': 191520,
#  'pained': 221616,
#  'nearby': 204851,
#  'waves': 323708,
#  'impatiently': 154860,
#  'meet': 190863,
#  'under': 312313,
#  'gazebo': 126622,
#  'precisely': 234857,
#  'minutes': 194989,
#  'suddenly': 286879,
#  'two': 309659,
#  'giggling': 128811,
#  'girls': 129321,
#  'appear': 30939,
#  'chattaways': 64733,
#  'faith': 111585,
#  'secret': 261875,
#  'telling': 294121,
#  'much': 201438,
#  'fiona': 116309,
#  'perhaps': 226522,
#  'shouldnt': 267906,
#  'decided': 85337,
#  'should': 267816,
#  'surprised': 288636,
#  'brought': 54006,
#  'fact': 111257,
#  'wonder': 330688,
#  'knows': 171689,
#  'swim': 289694,
#  'naked': 203678,
#  'havershims': 141145,
#  'pond': 232595,
#  'starts': 281984,
#  'walk': 321906,
#  'toward': 304700,
#  'blurts': 49009,
#  'going': 131101,
#  'ask': 33929,
#  'dead': 84661,
#  'sister': 270531,
#  'margaret': 187353,
#  'away': 36974,
#  'ruined': 254710,
#  'surprise': 288630,
#  'strangle': 284683,
#  'went': 325419,
#  'effort': 101058,
#  'theyve': 297872,
#  'come': 71733,
#  'engagement': 104355,
#  'yes': 334810,
#  'want': 322414,
#  'marry': 187884,
#  'better': 45386,
#  'blows': 48704,
#  'nose': 209701,
#  'studies': 285822,
#  'contents': 74696,
#  'kerchief': 169262,
#  'folds': 119282,
#  'pocket': 231667,
#  'youll': 336041,
#  'soon': 276295,
#  'pretty': 235753,
#  'forever': 120200,
#  'end': 104023,
#  'aunt': 36154,
#  'imogene': 154766,
#  'look': 181804,
#  'middleaged': 193318,
#  'overrouged': 219975,
#  'cheeks': 65035,
#  'yellowing': 334671,
#  'burden': 55795,
#  'happy': 139884,
#  'lowell': 182891,
#  'life': 178420,
#  'perfect': 226400,
#  'already': 26100,
#  'ascots': 33654,
#  'looms': 182024,
#  'hers': 144253,
#  'dear': 84894,
#  'shall': 265293,
#  'leisurely': 176823,
#  'stroll': 285461,
#  'jerks': 163783,
#  'quickly': 240715,
#  'rose': 253393,
#  'steers': 282643,
#  'fast': 112504,
#  'clip': 69090,
#  'dreaded': 96052,
#  'decline': 85459,
#  'aristocracy': 32415,
#  'ugly': 310737,
#  'grandchildren': 133029,
#  'lovely': 182748,
#  'bound': 51339,
#  'produce': 236658,
#  'little': 180082,
#  'gasps': 126214,
#  'imbeciles': 154393,
#  'gardeners': 125883,
#  'planted': 230423,
#  'roses': 253477,
#  'specifically': 278036,
#  'asked': 33939,
#  'red': 245168,
#  'paint': 221663,
#  'strangely': 284661,
#  'odd': 212595,
#  'along': 25970,
#  'hurries': 151196,
#  'path': 224065,
#  'hears': 141983,
#  'jingling': 164340,
#  'sound': 276957,
#  'son': 275974,
#  'extremely': 110312,
#  'delicate': 86583,
#  'digestion': 90150,
#  'something': 275735,
#  'large': 174558,
#  'dart': 83564,
#  'nasty': 204268,
#  'enjoy': 104585,
#  'setting': 264419,
#  'dogs': 93407,
#  'dawdle': 84027,
#  'serve': 264162,
#  'wrong': 332348,
#  'foods': 119609,
#  'blockage': 48278,
#  'standing': 281520,
#  'hind': 146152,
#  'staring': 281786,
#  'directly': 90797,
#  'blinks': 48151,
#  'darts': 83591,
#  'behind': 43772,
#  'tree': 306150,
#  '10': 818,
#  'shout': 267946,
#  'pay': 224639,
#  'attention': 35601,
#  'easily': 99427,
#  'saying': 258435,
#  'couldnt': 77134,
#  'more': 199459,
#  'interested': 158389,
#  'excuse': 109123,
#  'dives': 92291,
#  'wooded': 330866,
#  'area': 31971,
#  'moment': 198321,
#  'reeling': 245637,
#  'lands': 174195,
#  'shoulder': 267831,
#  'jumps': 166947,
#  'seeing': 262193,
#  'how': 149758,
#  'very': 318319,
#  'brocade': 53617,
#  'matter': 188781,
#  'cant': 59440,
#  'bothered': 51102,
#  'fancy': 111961,
#  'fiance': 114664,
#  'hes': 144395,
#  'prince': 236086,
#  'alas': 24224,
#  'cannot': 59356,
#  'unless': 313610,
#  'renounces': 247258,
#  'throne': 299803,
#  'isnt': 160577,
#  'tragic': 305278,
#  '11': 1544,
#  'backs': 38635,
#  'runs': 254980,
#  'sisters': 270554,
#  'kissing': 170634,
#  'woman': 330538,
#  'werehattie': 325507,
#  'old': 214631,
#  'friend': 122571,
#  'close': 69299,
#  'bright': 53237,
#  'highly': 145376,
#  'flustered': 118849,
#  'mention': 191768,
#  'confused': 73689,
#  'need': 205235,
#  'trust': 307673,
#  'marriage': 187833,
#  'annoyed': 29149,
#  'told': 302908,
#  'shadows': 265109,
#  'pillars': 228993,
#  'fall': 111702,
#  'prison': 236203,
#  'bars': 40889,
#  'glances': 129735,
#  'string': 285317,
#  'quartet': 240327,
#  'discreetly': 91262,
#  'positioned': 233433,
#  'bows': 51572,
#  'poised': 232009,
#  'drops': 96784,
#  'knee': 171184,
#  'notices': 210068,
#  'artist': 33386,
#  'immortalizing': 154715,
#  '12': 2192,
#  'frantically': 121729,
#  'brushes': 54315,
#  'lets': 177534,
#  'crawl': 78632,
#  'onto': 216185,
#  'finger': 116092,
#  'places': 230133,
#  'gently': 127530,
#  'branch': 52227,
#  'you1l': 335719,
#  'wash': 322972,
#  'motioning': 200293,
#  'below': 44280,
#  'watching': 323319,
#  'question': 240577,
#  'hangs': 139599,
#  'air': 23452,
#  'unsure': 314469,
#  'herself': 144271,
#  'future': 124539,
#  'sanity': 257397,
#  'stammers': 281413,
#  'iite': 153762,
#  'expects': 109603,
#  'toand': 302334,
#  'lordand': 182191,
#  'lastand': 174824,
#  'likebut': 178929,
#  'happening': 139819,
#  'quicklyi': 240724,
#  'thinkii': 298241,
#  'leaning': 176028,
#  'pillar': 228987,
#  'glaring': 129766,
#  'undisguised': 312734,
#  'impatience': 154855,
#  'meadow': 190114,
#  'follows': 119418,
#  'across': 20277,
#  'wait': 321632,
#  'loses': 182331,
#  'sight': 269257,
#  'peeks': 225312,
#  'over': 219517,
#  'hedgerow': 142442,
#  'stumped': 286005,
#  'around': 32862,
#  '13': 2891,
#  'paw': 224584,
#  'reaches': 243817,
#  'grasps': 133260,
#  'ankle': 28923,
#  'quick': 240667,
#  'jerk': 163763,
#  'keeps': 168918,
#  'screaming': 260545,
#  'tumbles': 308429,
#  'heels': 142561,
#  'grabs': 132755,
#  'walls': 322151,
#  'which': 326820,
#  'hung': 150988,
#  'paintings': 221699,
#  'ancient': 27659,
#  'maps': 187137,
#  'cracked': 78243,
#  'mirrors': 195191,
#  'demonic': 86948,
#  'masks': 188281,
#  'etc': 107358,
#  'books': 50445,
#  'jam': 162655,
#  'jars': 163018,
#  'crystal': 80346,
#  'ball': 39575,
#  'badger': 38908,
#  'claw': 68455,
#  'monkeys': 198782,
#  'human': 150664,
#  'skull': 271602,
#  'frantic': 121723,
#  'stop': 284094,
#  'falls': 111758,
#  'begins': 43676,
#  'grow': 134864,
#  'passes': 223808,
#  'still': 283420,
#  'seems': 262266,
#  'hours': 149342,
#  'hall': 138499,
#  'wham': 326065,
#  'hits': 146727,
#  'bottom': 51189,
#  'smacking': 273071,
#  'wooden': 330869,
#  'floor': 118375,
#  'ah': 22712,
#  'wind': 328858,
#  'knocked': 171417,
#  'rubbing': 254467,
#  'bump': 55518,
#  'many': 187037,
#  'doors': 94428,
#  'gets': 128121,
#  'tries': 306702,
#  'locked': 180979,
#  'another': 29285,
#  'knocks': 171451,
#  'hello': 143096,
#  'anyone': 30100,
#  'answer': 29430,
#  'moves': 200763,
#  'every': 108282,
#  'threelegged': 299519,
#  'table': 290802,
#  'small': 273100,
#  'key': 169437,
#  'sitting': 270693,
#  'picks': 228468,
#  'lock': 180964,
#  'few': 114429,
#  'comes': 71808,
#  'upon': 315126,
#  'curtain': 81215,
#  'aside': 33888,
#  'reveal': 249064,
#  'feet': 113566,
#  'high': 145215,
#  'fits': 116972,
#  'opens': 216861,
#  'bends': 44472,
#  'side': 268861,
#  'fountain': 120965,
#  'fit': 116941,
#  'shoulders': 267875,
#  'stuck': 285769,
#  'replaces': 247543,
#  'bottle': 51155,
#  'person': 226851,
#  'put': 239276,
#  'someone': 275650,
#  '14': 3330,
#  'label': 173300,
#  'drink': 96420,
#  'sniffs': 274189,
#  'recoils': 244884,
#  'shrugs': 268337,
#  'shudders': 268421,
#  'gags': 125092,
#  'coughs': 77088,
#  'taste': 292521,
#  'getting': 128152,
#  'larger': 174590,
#  'curious': 81087,
#  'shrinks': 268279,
#  'pov': 234070,
#  'loom': 182016,
#  'above': 19086,
#  'step': 282844,
#  'trips': 306937,
#  'nowoversized': 210609,
#  'clothes': 69561,
#  'dragging': 95795,
#  'open': 216743,
#  'groans': 134476,
#  'realizes': 244129,
#  'done': 93888,
#  'gold': 131179,
#  'keyhole': 169468,
#  'hear': 141918,
#  'voices': 320162,
#  'watch': 323260,
#  '0s': 770,
#  'first': 116665,
#  'dormouse': 94699,
#  'right': 250249,
#  'certain': 63380,
#  'attempts': 35569,
#  'climb': 68992,
#  'leg': 176597,
#  'tangled': 291891,
#  'toobig': 303468,
#  'slides': 272376,
#  'box': 51593,
#  'unseen': 314240,
#  'sort': 276688,
#  'prank': 234598,
#  'amused': 27360,
#  'cake': 58089,
#  'eat': 99526,
#  'written': 332322,
#  'ornate': 217816,
#  'icing': 152629,
#  'considers': 74269,
#  '15': 3723,
#  '16': 4149,
#  '17': 4526,
#  'tiny': 301503,
#  'bite': 47107,
#  'whoosh': 327703,
#  'shoots': 267472,
#  'upward': 315411,
#  'rapidly': 242852,
#  'growing': 134877,
#  'buttons': 56747,
#  'pop': 232883,
#  'seams': 261397,
#  'strained': 284618,
#  'skirt': 271479,
#  'shorter': 267613,
#  'ceiling': 62730,
#  'closerher': 69415,
#  'grazes': 133502,
#  'relieved': 246659,
#  'crouching': 79845,
#  'give': 129496,
#  'swallow': 289217,
#  'shivers': 267141,
#  'steps': 282971,
#  'underland': 312439,
#  'enters': 104985,
#  'fantastical': 112082,
#  'bizarre': 47236,
#  'illogical': 154112,
#  'dangerous': 82995,
#  'absurd': 19305,
#  'brown': 54039,
#  'statues': 282236,
#  'broken': 53738,
#  'overgrown': 219754,
#  'mossy': 200053,
#  'bellowsneezing': 44191,
#  'green': 133730,
#  'pig': 228777,
#  'dashes': 83654,
#  'tall': 291611,
#  'flowers': 118667,
#  'gaunt': 126466,
#  'haunted': 141010,
#  'faces': 111125,
#  'shabby': 265002,
#  'thin': 298052,
#  'birds': 46874,
#  'stalk': 281344,
#  'dragonflies': 95816,
#  'horseflies': 148794,
#  'enormous': 104709,
#  'gnats': 130457,
#  'fierce': 114956,
#  'battle': 41654,
#  'sky': 271647,
#  'curiouser': 81089,
#  'eye': 110448,
#  'glasses': 129817,
#  'walking': 321950,
#  'stick': 283257,
#  'female': 113853,
#  'breeches': 52784,
#  'boys': 51803,
#  'arms': 32671,
#  'thrown': 299931,
#  'each': 98877,
#  'others': 218409,
#  'dee': 85642,
#  'dum': 97612,
#  'stitched': 283722,
#  'collars': 71253,
#  'convinced': 75477,
#  'throws': 299942,
#  'hands': 139355,
#  'gratitude': 133335,
#  'weeks': 324500,
#  'trailing': 305319,
#  'next': 206611,
#  'almost': 25863,
#  'eaten': 99541,
#  'animals': 28808,
#  'entirely': 105082,
#  'unclothed': 312069,
#  'theirshukm': 296581,
#  'public': 238213,
#  'avert': 36723,
#  'talking': 291567,
#  'flower': 118639,
#  'anything': 30147,
#  'because': 42777,
#  'tweedledee': 309231,
#  'might': 193764,
#  'tweedledum': 309232,
#  'aint': 23413,
#  'nohow': 208571,
#  'may': 189132,
#  'shakes': 265235,
#  'speaking': 277911,
#  'tweedleehes': 309233,
#  'contrariwise': 75171,
#  'imtweedledum': 155316,
#  'stweedledee': 286173,
#  'consult': 74489,
#  'absolem': 19243,
#  'exactly': 108752,
#  'arm': 32508,
#  'ill': 153991,
#  'escort': 106798,
#  'being': 43866,
#  'turn': 308785,
#  'tug': 308312,
#  'between': 45477,
#  'leave': 176191,
#  'let': 177451,
#  'family': 111874,
#  'trait': 305393,
#  'tweedles': 309234,
#  'both': 51092,
#  'start': 281911,
#  'humanfaced': 150675,
#  'gossip': 132280,
#  'pass': 223710,
#  'wise': 329579,
#  'absolute': 19251,
#  '18': 4842,
#  'mushroom': 202501,
#  'forest': 120161,
#  'enter': 104952,
#  'mushrooms': 202506,
#  'surrounded': 288712,
#  'mist': 195569,
#  'form': 120353,
#  'ahead': 22797,
#  'rises': 250912,
#  'steady': 282392,
#  'plume': 231379,
#  'coming': 71927,
#  'hookah': 148267,
#  '19': 5199,
#  'smoking': 273633,
#  'iswho': 160899,
#  'smoke': 273568,
#  'rings': 250687,
#  'mean': 190172,
#  'ought': 218647,
#  'stupid': 286074,
#  'girl': 129235,
#  'unroll': 314148,
#  'oraculum': 217243,
#  ...}

# %% [markdown]
# ### BoW logistic regression
# The logistic regression was run using the lbfgs, the linear and the saga solver and different penalty terms were tested. Different numbers of max iterations and C (inverse regularization parameter) were tested, too.
# The lbfgs solver did not converge, so it was not included in the param grid search below.
#
# The param grid search was a bit flawed, in that it would suggest a model which did not converge.
# The final model included:

# %%
# Example parameter grid for Logistic Regression
param_grid = {
    'C': [0.0001, 0.001, 0.01],  # Regularization strength (inverse, smaller value = more regularization)
    'penalty': ['l1', 'l2'],               # Type of regularization
    'solver': ['liblinear', 'saga'],
    'max_iter': [500]       
}

# Define the logistic regression model
log_reg = LogisticRegression(random_state=42, max_iter = 500)

# Set up GridSearchCV
grid_search = GridSearchCV(log_reg, param_grid, cv=5, scoring='f1', n_jobs=-1)

# Fit the model to the training data
grid_search.fit(features_train, y_train)

# Output the best hyperparameters found by GridSearchCV
print("Best parameters:", grid_search.best_params_)
print("Best F1 score:", grid_search.best_score_)

# You can also access the best estimator (model) directly
best_model = grid_search.best_estimator_

# evaluate on validation dataset
val_score = best_model.score(features_val, y_val)
print("Validation dataset accuracy with best model:", val_score)

# %% [markdown]
# {'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}
# 'C': 0.01, 'penalty': 'l1', 'solver': 'saga'}
#
# previous: C=1, l2 (default), liblinear, max_iter = 500)
#
# l1, saga, C = 0.001, and max iter =

# %%
#initializing logistic regression model
clf_log_reg = LogisticRegression(
    penalty = 'elasticnet', # used elasticnet to use both the L1 and L2 penalty terms
    C = 0.001, # added more regularization
    random_state=42, 
    solver = 'saga',
    max_iter = 10000, #upped the number of iterations from 500 to 1000 to make the model converge
    l1_ratio = 0.5).fit(features_train, y_train) # the ratio of the penalty terms is 50/50

# %%
# save / reload model
#pkl.dump(clf_log_reg, file=open(f'/work/classes/NLP_exam/3_model_selection/output/models/BoW_log_reg_elasticnet_saga.pkl', 'wb')) # save the model
#clf_log_reg = pkl.load(open('/work/classes/NLP_exam/3_model_seleection/output/models/BoW_log_reg_elasticnet_saga.pkl','rb'))

# %%
# evaluate model on validation dataset and save performance metrics
performance_df = pd.DataFrame()
model = clf_log_reg

for x, y, nsplit in zip([features_train, features_val, features_test],
                        [y_train, y_val, y_test],
                        ['train', 'val', 'test']):
    mean_accuracy_score = model.score(x, y) 
    preds = model.predict(x)
    f1 = f1_score(y, preds)
    class_report = classification_report(y, preds, output_dict = True)
    roc_auc = roc_auc_score(np.array(y), model.predict_proba(x)[:,1]) # takes the probabiltiy of label = 1 (passing the bechdel-test)
   # roc_curve_calc = roc_curve(np.array(y), clf_log_reg.predict_proba(x)[:,1])#, pos_label = 1)

    # Create a dictionary with metrics for the current split
    metrics = {
        'model': 'BoW_log_reg',
        'split': nsplit,
        'mean_acc_score': round(mean_accuracy_score, 4),
        'f1_score': round(f1, 4),
        'cr_label0_precision': class_report['0']['precision'],
        'cr_label0_recall': class_report['0']['recall'],
        'cr_label0_f1_score': class_report['0']['f1-score'],
        'cr_label0_support': class_report['0']['support'],
        'cr_label1_precision': class_report['1']['precision'],
        'cr_label1_recall': class_report['1']['recall'],
        'cr_label1_f1_score': class_report['1']['f1-score'],
        'cr_label1_support': class_report['1']['support'],
        'roc_auc': roc_auc#,
        #'roc_curve': roc_curve_calc
    }
    
    # Convert the dictionary to a DataFrame and concatenate it with the main DataFrame
    performance_df = pd.concat([performance_df, pd.DataFrame([metrics])], ignore_index=True)

# Display the performance metrics
performance_df
# Out:
#          model  split  mean_acc_score  f1_score  cr_label0_precision  \
# 0  BoW_log_reg  train          0.7934    0.7869             0.772487
# 1  BoW_log_reg    val          0.7797    0.7665             0.747475
# 2  BoW_log_reg   test          0.7022    0.6826             0.673267
#
#    cr_label0_recall  cr_label0_f1_score  cr_label0_support  \
# 0          0.828369            0.799452              705.0
# 1          0.840909            0.791444               88.0
# 2          0.772727            0.719577               88.0
#
#    cr_label1_precision  cr_label1_recall  cr_label1_f1_score  \
# 0             0.817221          0.758766            0.786909
# 1             0.820513          0.719101            0.766467
# 2             0.740260          0.633333            0.682635
#
#    cr_label1_support   roc_auc
# 0              713.0  0.866420
# 1               89.0  0.867339
# 2               90.0  0.746338

# %% [markdown]
# ### BoW random forest
#
# To select the hyperparameters of the model, I performed a randomized search, which randomly puts together x number of combinations of the different hyperparameter values (here 10 combinations), performs five-fold cross validation and finally estimates the best parameters given the scoring metric which I've given the model (here, f1).

# %%
## randomized search
# Define the parameter grid
param_grid = {
    'n_estimators': [10, 50, 100], # number of trees - deafult is 10
    'max_depth': [5, 10, 20],      # max number of splits/leaves (leaf = node without children) - stopping criteria # default is none
    'min_samples_split': [2, 5, 10], # min. number of samples required to split an internal node, default is 2
    'max_features': [0.3, 0.6, 0.9], # proportion of features to max. use in a tree (subset proportion) - default is 1.0 (= all features)
    'ccp_alpha': [0.01, 0.1, 1.0] # minimal-cost complexity pruning - to overvoid overfitting, default 0.0 
}

# Initialize the Random Forest Classifier
clf_forest = RandomForestClassifier(random_state=42)

clf_forest_rs = RandomizedSearchCV(estimator=clf_forest, 
                            param_distributions=param_grid,
                            scoring='f1',
                            n_iter=10, 
                            cv=5,
                            verbose = 2,
                            n_jobs = -1)

# %%
randomized_search = clf_forest_rs.fit(features_train, y_train)

# get best parameters of the randomized search 
randomized_search.best_params_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END ccp_alpha=1.0, max_depth=20, max_features=0.3, min_samples_split=5, n_estimators=10; total time=  14.8s
# [CV] END ccp_alpha=1.0, max_depth=20, max_features=0.3, min_samples_split=5, n_estimators=10; total time=  14.9s
# [CV] END ccp_alpha=1.0, max_depth=20, max_features=0.3, min_samples_split=5, n_estimators=10; total time=  15.3s
# [CV] END ccp_alpha=1.0, max_depth=20, max_features=0.3, min_samples_split=5, n_estimators=10; total time=  16.2s
# [CV] END ccp_alpha=1.0, max_depth=20, max_features=0.3, min_samples_split=5, n_estimators=10; total time=  16.3s
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.9, min_samples_split=2, n_estimators=50; total time= 1.3min
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.9, min_samples_split=2, n_estimators=50; total time= 1.3min
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.9, min_samples_split=2, n_estimators=50; total time= 1.3min
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.9, min_samples_split=2, n_estimators=50; total time= 1.3min
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.9, min_samples_split=2, n_estimators=50; total time= 1.3min
# [CV] END ccp_alpha=1.0, max_depth=5, max_features=0.3, min_samples_split=2, n_estimators=100; total time= 1.1min
# [CV] END ccp_alpha=1.0, max_depth=5, max_features=0.3, min_samples_split=2, n_estimators=100; total time= 1.1min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.6, min_samples_split=10, n_estimators=50; total time= 1.6min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.6, min_samples_split=10, n_estimators=50; total time= 1.6min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.6, min_samples_split=10, n_estimators=50; total time= 1.6min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.6, min_samples_split=10, n_estimators=50; total time= 1.6min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.6, min_samples_split=10, n_estimators=50; total time= 1.7min
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, min_samples_split=5, n_estimators=100; total time= 1.8min
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, min_samples_split=5, n_estimators=100; total time= 1.9min
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, min_samples_split=5, n_estimators=100; total time= 1.9min
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, min_samples_split=5, n_estimators=100; total time= 1.9min
# [CV] END ccp_alpha=0.01, max_depth=5, max_features=0.6, min_samples_split=5, n_estimators=100; total time= 2.0min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.9, min_samples_split=10, n_estimators=50; total time= 2.1min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.9, min_samples_split=10, n_estimators=50; total time= 2.1min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.9, min_samples_split=10, n_estimators=50; total time= 2.2min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.9, min_samples_split=10, n_estimators=50; total time= 2.2min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.9, min_samples_split=10, n_estimators=50; total time= 2.3min
# [CV] END ccp_alpha=1.0, max_depth=5, max_features=0.3, min_samples_split=2, n_estimators=100; total time= 1.1min
# [CV] END ccp_alpha=1.0, max_depth=5, max_features=0.3, min_samples_split=2, n_estimators=100; total time= 1.1min
# [CV] END ccp_alpha=1.0, max_depth=5, max_features=0.3, min_samples_split=2, n_estimators=100; total time= 1.1min
# [CV] END ccp_alpha=0.01, max_depth=20, max_features=0.3, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.9, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END ccp_alpha=0.01, max_depth=20, max_features=0.3, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END ccp_alpha=0.01, max_depth=20, max_features=0.3, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.9, min_samples_split=10, n_estimators=50; total time= 1.2min
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.9, min_samples_split=10, n_estimators=50; total time= 1.2min
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.9, min_samples_split=10, n_estimators=50; total time= 1.2min
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.9, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END ccp_alpha=0.01, max_depth=20, max_features=0.3, min_samples_split=2, n_estimators=100; total time= 2.6min
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.9, min_samples_split=10, n_estimators=50; total time= 1.2min
# [CV] END ccp_alpha=0.01, max_depth=20, max_features=0.3, min_samples_split=2, n_estimators=100; total time= 2.6min
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.9, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.9, min_samples_split=2, n_estimators=100; total time= 2.4min
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.9, min_samples_split=10, n_estimators=50; total time= 1.2min
# [CV] END ccp_alpha=0.1, max_depth=5, max_features=0.9, min_samples_split=2, n_estimators=100; total time= 2.5min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.9, min_samples_split=5, n_estimators=50; total time= 1.9min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.9, min_samples_split=5, n_estimators=50; total time= 2.0min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.9, min_samples_split=5, n_estimators=50; total time= 2.1min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.9, min_samples_split=5, n_estimators=50; total time= 2.0min
# [CV] END ccp_alpha=0.01, max_depth=10, max_features=0.9, min_samples_split=5, n_estimators=50; total time= 1.9min
# {'n_estimators': 100,
#  'min_samples_split': 2,
#  'max_features': 0.3,
#  'max_depth': 20,
#  'ccp_alpha': 0.01}

# %%
# initializing random forest with the hyperparameters from the randomized search 
clf_forest = RandomForestClassifier(
    n_estimators = 100,
    min_samples_split = 2, 
    max_features = 0.3,
    max_depth = 20, 
    ccp_alpha = 0.01,
    random_state=42).fit(features_train, y_train)

# %%
model = clf_forest

for x, y, nsplit in zip([features_train, features_val, features_test],
                        [y_train, y_val, y_test],
                        ['train', 'val', 'test']):
    mean_accuracy_score = model.score(x, y) 
    preds = model.predict(x)
    f1 = f1_score(y, preds)
    class_report = classification_report(y, preds, output_dict = True)
    roc_auc = roc_auc_score(np.array(y), model.predict_proba(x)[:,1]) # takes the probabiltiy of label = 1 (passing the bechdel-test)
    
    # Create a dictionary with metrics for the current split
    metrics = {
        'model': 'BoW_rf',
        'split': nsplit,
        'mean_acc_score': round(mean_accuracy_score, 4),
        'f1_score': round(f1, 4),
        'cr_label0_precision': class_report['0']['precision'],
        'cr_label0_recall': class_report['0']['recall'],
        'cr_label0_f1_score': class_report['0']['f1-score'],
        'cr_label0_support': class_report['0']['support'],
        'cr_label1_precision': class_report['1']['precision'],
        'cr_label1_recall': class_report['1']['recall'],
        'cr_label1_f1_score': class_report['1']['f1-score'],
        'cr_label1_support': class_report['1']['support'],
        'roc_auc': roc_auc#,
        #'roc_curve': roc_curve_calc
    }
    
    # Convert the dictionary to a DataFrame and concatenate it with the main DataFrame
    performance_df = pd.concat([performance_df, pd.DataFrame([metrics])], ignore_index=True)

# Display the performance metrics
performance_df
# Out:
#          model  split  mean_acc_score  f1_score  cr_label0_precision  \
# 0  BoW_log_reg  train          0.7934    0.7869             0.772487
# 1  BoW_log_reg    val          0.7797    0.7665             0.747475
# 2  BoW_log_reg   test          0.7022    0.6826             0.673267
# 3       BoW_rf  train          0.7786    0.7711             0.757576
# 4       BoW_rf    val          0.7627    0.7439             0.725490
# 5       BoW_rf   test          0.6798    0.6503             0.647619
#
#    cr_label0_recall  cr_label0_f1_score  cr_label0_support  \
# 0          0.828369            0.799452              705.0
# 1          0.840909            0.791444               88.0
# 2          0.772727            0.719577               88.0
# 3          0.815603            0.785519              705.0
# 4          0.840909            0.778947               88.0
# 5          0.772727            0.704663               88.0
#
#    cr_label1_precision  cr_label1_recall  cr_label1_f1_score  \
# 0             0.817221          0.758766            0.786909
# 1             0.820513          0.719101            0.766467
# 2             0.740260          0.633333            0.682635
# 3             0.802731          0.741935            0.771137
# 4             0.813333          0.685393            0.743902
# 5             0.726027          0.588889            0.650307
#
#    cr_label1_support   roc_auc
# 0              713.0  0.866420
# 1               89.0  0.867339
# 2               90.0  0.746338
# 3              713.0  0.866319
# 4               89.0  0.850613
# 5               90.0  0.739899

# %%
# save / reload model
#pkl.dump(clf_forest, file=open(f'/work/classes/NLP_exam/3_model_selection/output/models/BoW_random_forest.pkl', 'wb')) # save the model
#clf_forest = pkl.load(open('/work/classes/NLP_exam/3_model_seleection/output/models/BoW_random_forest.pkl','rb'))

# %% [markdown]
# ### BoW support vector classifier (SVC)
#
# Here, I also perform a search for the best parameters, but this time I perform a gridsearch and not a randomized search. The difference is that the gridsearch performs an exhaustive search, that is, all possible combinations of hyperparameters are tested.

# %%
# Define parameter grid for GridSearchCV
param_grid = {'C': [0.1, 0.01, 1], 'kernel': ['linear', 'rbf']}

# Perform grid search
grid_search = GridSearchCV(SVC(random_state=42, probability=True), param_grid, cv=5, n_jobs=-1)
grid_search.fit(features_train, y_train)

# Best parameters from grid search
print("Best Parameters:", grid_search.best_params_)
clf_svm = grid_search.best_estimator_
# Out:
# Best Parameters: {'C': 1, 'kernel': 'rbf'}

# %%
# support vector maching # max_iter=500
clf_svc = SVC(C=1, kernel = 'rbf', probability=True, random_state = 42).fit(features_train, y_train)
# C = 1 and kernel = 'rbf' is the default hyperparameters of the SVC

# %%
model = clf_svc

for x, y, nsplit in zip([features_train, features_val, features_test], 
                        [y_train, y_val, y_test],
                        ['train', 'val', 'test']):
    mean_accuracy_score = model.score(x, y) 
    preds = model.predict(x)
    f1 = f1_score(y, preds)
    class_report = classification_report(y, preds, output_dict = True)

    # Get predicted probabilities for the positive class (class 1)
    y_pred_proba = model.predict_proba(x)[:, 1]  # Probabilities for class 1

    # Compute the ROC AUC score
    roc_auc = roc_auc_score(np.array(y), y_pred_proba)

    #roc_auc = roc_auc_score(np.array(y), clf_svm.predict_proba(x)[:,1]) # takes the probabiltiy of label = 1 (passing the bechdel-test)
   # roc_curve_calc = roc_curve(np.array(y), clf_log_reg.predict_proba(x)[:,1])#, pos_label = 1)

    # Create a dictionary with metrics for the current split
    metrics = {
        'model': 'BoW_svc',
        'split': nsplit,
        'mean_acc_score': round(mean_accuracy_score, 4),
        'f1_score': round(f1, 4),
        'cr_label0_precision': class_report['0']['precision'],
        'cr_label0_recall': class_report['0']['recall'],
        'cr_label0_f1_score': class_report['0']['f1-score'],
        'cr_label0_support': class_report['0']['support'],
        'cr_label1_precision': class_report['1']['precision'],
        'cr_label1_recall': class_report['1']['recall'],
        'cr_label1_f1_score': class_report['1']['f1-score'],
        'cr_label1_support': class_report['1']['support'],
        'roc_auc': roc_auc#,
        #'roc_curve': roc_curve_calc
    }
    
    # Convert the dictionary to a DataFrame and concatenate it with the main DataFrame
    performance_df = pd.concat([performance_df, pd.DataFrame([metrics])], ignore_index=True)


# Display the performance metrics
performance_df
# Out:
#          model  split  mean_acc_score  f1_score  cr_label0_precision  \
# 0  BoW_log_reg  train          0.7934    0.7869             0.772487
# 1  BoW_log_reg    val          0.7797    0.7665             0.747475
# 2  BoW_log_reg   test          0.7022    0.6826             0.673267
# 3       BoW_rf  train          0.7786    0.7711             0.757576
# 4       BoW_rf    val          0.7627    0.7439             0.725490
# 5       BoW_rf   test          0.6798    0.6503             0.647619
# 6      BoW_svc  train          0.8096    0.7861             0.750288
# 7      BoW_svc    val          0.7571    0.7152             0.695652
# 8      BoW_svc   test          0.7135    0.6623             0.658120
#
#    cr_label0_recall  cr_label0_f1_score  cr_label0_support  \
# 0          0.828369            0.799452              705.0
# 1          0.840909            0.791444               88.0
# 2          0.772727            0.719577               88.0
# 3          0.815603            0.785519              705.0
# 4          0.840909            0.778947               88.0
# 5          0.772727            0.704663               88.0
# 6          0.924823            0.828463              705.0
# 7          0.909091            0.788177               88.0
# 8          0.875000            0.751220               88.0
#
#    cr_label1_precision  cr_label1_recall  cr_label1_f1_score  \
# 0             0.817221          0.758766            0.786909
# 1             0.820513          0.719101            0.766467
# 2             0.740260          0.633333            0.682635
# 3             0.802731          0.741935            0.771137
# 4             0.813333          0.685393            0.743902
# 5             0.726027          0.588889            0.650307
# 6             0.903461          0.695652            0.786054
# 7             0.870968          0.606742            0.715232
# 8             0.819672          0.555556            0.662252
#
#    cr_label1_support   roc_auc
# 0              713.0  0.866420
# 1               89.0  0.867339
# 2               90.0  0.746338
# 3              713.0  0.866319
# 4               89.0  0.850613
# 5               90.0  0.739899
# 6              713.0  0.919259
# 7               89.0  0.847612
# 8               90.0  0.763510

# %%
# save / reload model
#pkl.dump(clf_svc, file=open(f'/work/classes/NLP_exam/3_model_selection/output/models/BoW_svc.pkl', 'wb')) # save the model
#clf_svc = pkl.load(open('/work/classes/NLP_exam/3_model_seleection/output/models/BoW_svc.pkl','rb'))

# %%
# save model performances
#performance_df.to_csv('/work/classes/NLP_exam/3_model_selection/output/performances_df.csv', index = False)
# reload if stopping mid-way
performance_df = pd.read_csv('/work/classes/NLP_exam/3_model_selection/output/performances_df.csv')

# %%
performance_df
# Out:
#          model  split  mean_acc_score  f1_score  cr_label0_precision  \
# 0  BoW_log_reg  train          0.7934    0.7869             0.772487
# 1  BoW_log_reg    val          0.7797    0.7665             0.747475
# 2  BoW_log_reg   test          0.7022    0.6826             0.673267
# 3       BoW_rf  train          0.7786    0.7711             0.757576
# 4       BoW_rf    val          0.7627    0.7439             0.725490
# 5       BoW_rf   test          0.6798    0.6503             0.647619
# 6      BoW_svc  train          0.8096    0.7861             0.750288
# 7      BoW_svc    val          0.7571    0.7152             0.695652
# 8      BoW_svc   test          0.7135    0.6623             0.658120
#
#    cr_label0_recall  cr_label0_f1_score  cr_label0_support  \
# 0          0.828369            0.799452              705.0
# 1          0.840909            0.791444               88.0
# 2          0.772727            0.719577               88.0
# 3          0.815603            0.785519              705.0
# 4          0.840909            0.778947               88.0
# 5          0.772727            0.704663               88.0
# 6          0.924823            0.828463              705.0
# 7          0.909091            0.788177               88.0
# 8          0.875000            0.751220               88.0
#
#    cr_label1_precision  cr_label1_recall  cr_label1_f1_score  \
# 0             0.817221          0.758766            0.786909
# 1             0.820513          0.719101            0.766467
# 2             0.740260          0.633333            0.682635
# 3             0.802731          0.741935            0.771137
# 4             0.813333          0.685393            0.743902
# 5             0.726027          0.588889            0.650307
# 6             0.903461          0.695652            0.786054
# 7             0.870968          0.606742            0.715232
# 8             0.819672          0.555556            0.662252
#
#    cr_label1_support   roc_auc
# 0              713.0  0.866420
# 1               89.0  0.867339
# 2               90.0  0.746338
# 3              713.0  0.866319
# 4               89.0  0.850613
# 5               90.0  0.739899
# 6              713.0  0.919259
# 7               89.0  0.847612
# 8               90.0  0.763510

# %% [markdown]
# ## Plotting BoW most frequent words

# %%
# plot distinct words in each label based on frequencies 

# fix variable names
X = features_train.copy()
labels = train_data['passed_bechdel']

# Get the vocabulary mapping (word to column index)
vocabulary = vectorizer.vocabulary_
words = np.array(list(vocabulary.keys()))
word_indices = np.array(list(vocabulary.values()))

# Separate the word frequencies by label
X_label_0 = X[labels == 0].toarray().sum(axis=0)  # Word frequencies for label 0
X_label_1 = X[labels == 1].toarray().sum(axis=0)  # Word frequencies for label 1

# Calculate the difference in frequencies between label 1 and label 0
frequency_diff = X_label_1 - X_label_0

# Apply threshold filtering: Keep words with |frequency_diff| >= 5
threshold = 5
valid_indices = np.where(np.abs(frequency_diff) >= threshold)[0]
filtered_frequency_diff = frequency_diff[valid_indices]
filtered_words = words[word_indices.argsort()][valid_indices]

# %%
# Find the top 10 words distinct to label 1
top_indices_distinct_label_1 = np.argsort(filtered_frequency_diff)[-10:][::-1]  # Largest positive differences
distinct_words_label_1 = filtered_words[top_indices_distinct_label_1]
distinct_frequencies_label_1 = filtered_frequency_diff[top_indices_distinct_label_1]

# Plot the distinct words for label 1
plt.figure(figsize=(10, 5))
plt.bar(distinct_words_label_1, distinct_frequencies_label_1, color='blue')
plt.title("Words Distinct to label 1 (passing the Bechdel test)")
plt.xlabel("Words")
plt.ylabel("Frequency Difference (Label 1 - Label 0)")
plt.xticks(rotation=45)
plt.tight_layout()
#plt.savefig('../figures/BoW_words_label1.jpeg', format='jpeg', dpi=300) 

plt.show()

# %%
# Find the top 10 words distinct to label 0
#top_indices_distinct_label_0 = np.argsort(filtered_frequency_diff)[:15]  # Largest negative differences
#distinct_words_label_0 = filtered_words[top_indices_distinct_label_0]
#distinct_frequencies_label_0 = filtered_frequency_diff[top_indices_distinct_label_0]

# Find the top 10 words distinct to label 1
top_indices_distinct_label_0 = np.argsort(filtered_frequency_diff)[:10]  # Largest positive differences
distinct_words_label_0 = filtered_words[top_indices_distinct_label_0]
distinct_frequencies_label_0 = filtered_frequency_diff[top_indices_distinct_label_0]

# Plot the distinct words for label 0
plt.figure(figsize=(10, 5))
plt.bar(distinct_words_label_0, -distinct_frequencies_label_0, color='red')  # Flip sign for better visualization
plt.title("Words Distinct to label 0 (not passing the Bechdel test)")
plt.xlabel("Words")
plt.ylabel("Frequency Difference (Label 0 - Label 1)")
plt.xticks(rotation=45)
plt.tight_layout()
#plt.savefig('../figures/BoW_words_label0.jpeg', format='jpeg', dpi=300) 

plt.show()

# %% [markdown]
# ### BoW wordclouds

# %%
# Step 1: Define and preprocess variables
X = features_train.copy()  # Frequency matrix
labels = train_data['passed_bechdel']  # Binary label (0 or 1)

# Get the vocabulary mapping (word to column index)
vocabulary = vectorizer.vocabulary_ # vectorizer has already been initialized above
words = np.array(list(vocabulary.keys()))
word_indices = np.array(list(vocabulary.values()))

# Separate the word frequencies by label
X_label_0 = X[labels == 0].toarray().sum(axis=0)  # Word frequencies for label 0
X_label_1 = X[labels == 1].toarray().sum(axis=0)  # Word frequencies for label 1

# Calculate the difference in frequencies between label 1 and label 0
frequency_diff = X_label_1 - X_label_0

# Apply threshold filtering: Keep words with |frequency_diff| >= 5
threshold = 5
valid_indices = np.where(np.abs(frequency_diff) >= threshold)[0]
filtered_frequency_diff = frequency_diff[valid_indices]
filtered_words = words[word_indices.argsort()][valid_indices]

# Step 2: Find distinct words for each label
# Top 50 words distinct to label 1
top_indices_distinct_label_1 = np.argsort(filtered_frequency_diff)[-50:][::-1]  # Largest positive differences
distinct_words_label_1 = filtered_words[top_indices_distinct_label_1]
distinct_frequencies_label_1 = filtered_frequency_diff[top_indices_distinct_label_1]

# Top 50 words distinct to label 0
top_indices_distinct_label_0 = np.argsort(filtered_frequency_diff)[:50]  # Largest negative differences
distinct_words_label_0 = filtered_words[top_indices_distinct_label_0]
distinct_frequencies_label_0 = filtered_frequency_diff[top_indices_distinct_label_0]

path = "/work/classes/NLP_exam/figures/"

# Step 3: Create WordClouds for the distinct words
def generate_wordcloud_from_filtered(words, frequencies, title, file_name):

    word_freq = dict(zip(words, np.abs(frequencies)))
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_freq)
    
    # Plot the WordCloud with a title
    plt.figure(figsize=(10, 6))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(title, fontsize=16)
    
    # Save the plot 
    plt.savefig(path + file_name, bbox_inches='tight', dpi=300)
    plt.show()

# WordCloud for distinct words in label 0
generate_wordcloud_from_filtered(
    distinct_words_label_0, 
    distinct_frequencies_label_0, 
    "Distinct Words for Label 0",
    "wordcloud_label0.jpeg")

# WordCloud for distinct words in label 1
generate_wordcloud_from_filtered(
    distinct_words_label_1, 
    distinct_frequencies_label_1, 
    "Distinct Words for Label 1", 
    "wordcloud_label1.jpeg")

# %%
# stopwords_custom = stopwords = [
#     'a', 'about', 'above', 'after', 'again', 'against', 'all', 'am', 'an', 'and', 'any', 
#     'are', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 
#     'both', 'but', 'by', "can't", 'cannot', 'could', "couldn't", 'did', "didn't", 'do', 'does', 
#     "doesn't", 'doing', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 
#     "hadn't", 'has', "hasn't", 'have', "haven't", 'having', 
#     'here', "here's", 'how', "how's", 'i', "i'd", "i'll", 
#     "i'm", "i've", 'if', 'in', 'into', 'is', "isn't", 'it', "it's", 'its', 'itself', 'let\'s', 'me', 
#     'more', 'most', "mustn't", 'my', 'myself', 'no', 'nor', 'not', 'of', 'off', 'on', 'once', 'only', 
#     'or', 'other', 'ought', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 'same', "shan't",
#     'should', "shouldn't", 'so', 'some', 'such', 'than', 'that', "that's", 
#     'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', "there's", 'these', 'they', 
#     "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 
#     'until', 'up', 'very', 'was', "wasn't", 'we', "we'd", "we'll", "we're", "we've", 'were', 
#     "weren't", 'what', "what's", 'when', "when's", 'where', "where's", 'which', 'while', 'who', 
#     "who's", 'whom', 'why', "why's", 'with', "won't", 'would', "wouldn't", 'you', "you'd", "you'll", 
#     "you're", "you've", 'your', 'yours', 'yourself', 'yourselves'
# ]

# %% [markdown]
# ## TF-IDF

# %% [markdown]
# checkout class4 to see how to use this with a neural logistric regression classifier xx

# %%
# initializing the new tf-idf vectorizer
vectorizer = TfidfVectorizer()

# fitting the training data
tf_idf_features_train = vectorizer.fit_transform(texts_train)

# transforming the validation and test data
tf_idf_features_val = vectorizer.transform(texts_val)
tf_idf_features_test = vectorizer.transform(texts_test)

# y values are the same as before

# %%
# sanity checking
print(tf_idf_features_train.shape)
vectorizer.vocabulary_
# Out:
# (1418, 339126)
# {'alice': 24707,
#  'by': 57022,
#  'linda': 179313,
#  'woolverton': 331083,
#  'based': 41067,
#  'on': 215199,
#  'alices': 24717,
#  'adventures': 21218,
#  'in': 155352,
#  'wonderland': 330728,
#  'through': 299850,
#  'the': 296163,
#  'looking': 181877,
#  'glass': 129786,
#  'lewis': 177850,
#  'carroll': 60852,
#  '9908': 16306,
#  'white': 327154,
#  'shooting': 267457,
#  'script': 260843,
#  '102808': 1088,
#  'blue': 48766,
#  'revised': 249266,
#  'pages': 221513,
#  'fade': 111324,
#  'ext': 109990,
#  'london': 181445,
#  '1855': 5003,
#  'night': 207163,
#  'warm': 322703,
#  'light': 178648,
#  'shines': 266736,
#  'from': 122918,
#  'study': 285868,
#  'of': 212872,
#  'gracious': 132809,
#  'kingsley': 170421,
#  'home': 147723,
#  'man': 186254,
#  'silhouetted': 269586,
#  'window': 328945,
#  'speaks': 277925,
#  'with': 329731,
#  'ardor': 31950,
#  'int': 158081,
#  'cont': 74527,
#  'charles': 64479,
#  'has': 140640,
#  'just': 167187,
#  'described': 87760,
#  'his': 146397,
#  'new': 206267,
#  'venture': 317957,
#  'to': 302274,
#  'friends': 122609,
#  'including': 155736,
#  'lord': 182188,
#  'ascot': 33652,
#  'you': 335714,
#  'have': 141050,
#  'finally': 115882,
#  'lost': 182364,
#  'your': 336187,
#  'senses': 263515,
#  'colleague': 71265,
#  'this': 298525,
#  'is': 160133,
#  'impossible': 155093,
#  'for': 119875,
#  'some': 275555,
#  'gentlemen': 127490,
#  'only': 215955,
#  'way': 323775,
#  'achieve': 19905,
#  'believe': 44034,
#  'it': 160917,
#  'possible': 233519,
#  'that': 295772,
#  'kind': 170294,
#  'thinking': 298245,
#  'could': 77104,
#  'ruin': 254708,
#  'im': 154265,
#  'willing': 328648,
#  'take': 291334,
#  'chance': 64091,
#  'imagine': 154339,
#  'trading': 305208,
#  'posts': 233728,
#  'rangoon': 242686,
#  'bangkok': 40049,
#  'jakarta': 162601,
#  'he': 141524,
#  'stops': 284178,
#  'nine': 207629,
#  'yearold': 334383,
#  'daughter': 83836,
#  'stands': 281558,
#  'at': 34777,
#  'door': 94285,
#  'her': 143667,
#  'nightgown': 207266,
#  'clearly': 68628,
#  'frightened': 122697,
#  'goes': 130982,
#  'contd': 74606,
#  'nightmare': 207327,
#  'again': 22047,
#  'she': 265831,
#  'nods': 208451,
#  'takes': 291384,
#  'hand': 139028,
#  'and': 27704,
#  'turns': 308867,
#  'guests': 135576,
#  'wont': 330795,
#  'be': 42190,
#  'long': 181484,
#  'young': 336095,
#  'bedroom': 43089,
#  'later': 174944,
#  'sits': 270662,
#  'bed': 42942,
#  'listening': 179881,
#  'utmost': 316132,
#  'seriousness': 264036,
#  'falling': 111732,
#  'down': 95300,
#  'dark': 83337,
#  'hole': 147411,
#  'then': 296893,
#  'see': 262094,
#  'strange': 284654,
#  'creatures': 78842,
#  'what': 326143,
#  'continued': 74894,
#  'well': 324873,
#  'theres': 297308,
#  'dodo': 93157,
#  'bird': 46834,
#  'rabbit': 241397,
#  'waistcoat': 321615,
#  'smiling': 273444,
#  'cat': 61476,
#  'didnt': 89322,
#  'know': 171515,
#  'cats': 61795,
#  'smile': 273388,
#  'neither': 205567,
#  'did': 89245,
#  'oh': 213748,
#  'caterpillar': 61652,
#  'hmm': 146858,
#  'do': 92689,
#  'think': 298213,
#  'ive': 161796,
#  'gone': 131494,
#  'round': 253824,
#  'bend': 44442,
#  'feels': 113528,
#  'forehead': 120083,
#  'as': 33506,
#  'if': 153223,
#  'fever': 114410,
#  'afraid': 21793,
#  'so': 274610,
#  'youre': 336212,
#  'mad': 184889,
#  'bonkers': 50186,
#  'off': 212966,
#  'head': 141553,
#  'but': 56370,
#  'i1l': 151966,
#  'tell': 294091,
#  'secretall': 261877,
#  'best': 45177,
#  'people': 226055,
#  'are': 31964,
#  'smiles': 273407,
#  'leans': 176038,
#  'against': 22135,
#  'him': 145783,
#  'its': 161426,
#  'dream': 96073,
#  'nothing': 209979,
#  'can': 59014,
#  'harm': 140331,
#  'there': 297202,
#  'get': 128037,
#  'too': 303455,
#  'always': 26409,
#  'wake': 321808,
#  'up': 314852,
#  'like': 178914,
#  'pinches': 229142,
#  'screams': 260569,
#  'back': 38369,
#  'cut': 81392,
#  'outskirts': 219316,
#  'ten': 294311,
#  'years': 334389,
#  'horsedrawn': 148786,
#  'carriage': 60784,
#  'careens': 60242,
#  'road': 251393,
#  'full': 123834,
#  'gallop': 125347,
#  'day': 84090,
#  'verge': 318081,
#  'womanhood': 330559,
#  'beautiful': 42624,
#  'slightly': 272404,
#  'offkilter': 213311,
#  'sees': 262340,
#  'world': 331483,
#  'different': 89553,
#  'eyes': 110580,
#  'than': 295641,
#  'other': 218362,
#  'age': 22232,
#  'presently': 235483,
#  'shes': 266359,
#  'tired': 301632,
#  'grumpy': 135044,
#  'mother': 200153,
#  'fusses': 124492,
#  'wild': 328432,
#  'mane': 186468,
#  'blonde': 48368,
#  'hair': 137464,
#  'must': 202649,
#  'we': 324002,
#  'go': 130523,
#  'doubt': 95094,
#  'they1ll': 297741,
#  'notice': 210051,
#  'never': 206182,
#  'arrive': 33117,
#  'helen': 142875,
#  'they': 297732,
#  'will': 328576,
#  'reties': 248744,
#  'waist': 321608,
#  'sash': 257838,
#  'feeling': 113501,
#  'corset': 76673,
#  'wheres': 326715,
#  'pulls': 238560,
#  'dress': 96241,
#  'bare': 40465,
#  'legs': 176735,
#  'no': 208209,
#  'stockings': 283831,
#  'them': 296658,
#  'not': 209827,
#  'properly': 237160,
#  'dressed': 96250,
#  'whos': 327763,
#  'say': 258390,
#  'proper': 237156,
#  'was': 322911,
#  'agreed': 22608,
#  'wearing': 324163,
#  'codfish': 70680,
#  'would': 331812,
#  'wear': 324137,
#  'me': 190078,
#  'please': 230861,
#  'today': 302501,
#  'frustrated': 123342,
#  'looks': 181928,
#  'out': 218820,
#  'mutters': 202818,
#  'father': 112682,
#  'laughed': 175208,
#  'hurt': 151232,
#  'mothers': 200234,
#  'face': 111019,
#  'instantly': 157878,
#  'regrets': 246160,
#  'words': 331234,
#  'sorry': 276613,
#  'sleep': 272174,
#  'last': 174816,
#  'pats': 224279,
#  'forgiving': 120289,
#  'gesture': 128015,
#  'bad': 38846,
#  'dreams': 96109,
#  'one': 215408,
#  'same': 256927,
#  'ever': 108129,
#  'since': 269994,
#  'remember': 246879,
#  'thats': 295972,
#  'normal': 209515,
#  'dont': 94045,
#  'most': 200055,
#  'removes': 247057,
#  'own': 220347,
#  'jewelry': 164056,
#  'puts': 239331,
#  'now': 210400,
#  'manage': 186280,
#  'estate': 107136,
#  'gardens': 125898,
#  'garden': 125872,
#  'party': 223551,
#  'swing': 289739,
#  'everyone': 108336,
#  'turned': 308811,
#  'their': 296563,
#  'summer': 287431,
#  'finery': 116058,
#  'play': 230670,
#  'croquet': 79611,
#  'great': 133586,
#  'lawn': 175556,
#  'skiffs': 271333,
#  'drift': 96361,
#  'lazily': 175725,
#  'meandering': 190192,
#  'river': 251093,
#  'approaches': 31256,
#  'lady': 173619,
#  'fixed': 117200,
#  'unnatural': 313774,
#  'stately': 282059,
#  'aristocratic': 32418,
#  'redfaced': 245312,
#  'annoyance': 29146,
#  'thought': 299160,
#  'youd': 335852,
#  'hamish': 138883,
#  'waiting': 321680,
#  'dance': 82879,
#  'pushes': 239168,
#  'realize': 244121,
#  'past': 223901,
#  'four': 120974,
#  'everything': 108374,
#  'rushed': 255093,
#  'am': 26453,
#  'mind': 194418,
#  'rushes': 255099,
#  'forgive': 120282,
#  'my': 202932,
#  'wife': 328250,
#  'been': 43339,
#  'planning': 230380,
#  'affair': 21594,
#  'twenty': 309346,
#  'were': 325477,
#  'here': 143776,
#  'condolences': 73410,
#  'madame': 184902,
#  'husband': 151274,
#  'often': 213591,
#  'truly': 307595,
#  'vision': 319715,
#  'thank': 295660,
#  'hope': 148452,
#  'taken': 291364,
#  'advantage': 21198,
#  'misfortune': 195358,
#  'course': 77508,
#  'pleased': 230876,
#  'youve': 336564,
#  'purchased': 238928,
#  'company': 72519,
#  'fool': 119644,
#  'investing': 159302,
#  'when': 326618,
#  'had': 137118,
#  'quadrille': 240131,
#  'does': 93211,
#  'line': 179360,
#  'who': 327416,
#  'after': 21872,
#  'refined': 245810,
#  'immaculate': 154599,
#  'arrogance': 33153,
#  'tire': 301630,
#  'contrary': 75172,
#  'find': 115943,
#  'invigorating': 159333,
#  'struts': 285656,
#  'peacock': 224936,
#  'laughs': 175243,
#  'amuse': 27359,
#  'sudden': 286865,
#  'all': 25325,
#  'ladies': 173563,
#  'top': 303722,
#  'hats': 140942,
#  'men': 191544,
#  'bonnets': 50206,
#  'doesnt': 93231,
#  'even': 108027,
#  'crack': 78229,
#  'keep': 168897,
#  'visions': 319725,
#  'yourself': 336319,
#  'remain': 246785,
#  'silent': 269550,
#  'fades': 111334,
#  'without': 329847,
#  'whole': 327526,
#  'flock': 118320,
#  'geese': 126973,
#  'overhead': 219769,
#  'distracted': 92087,
#  'bumps': 55549,
#  'into': 158901,
#  'dancers': 82907,
#  'front': 123058,
#  'pardon': 222955,
#  'us': 315688,
#  'miss': 195469,
#  'where': 326677,
#  'wondering': 330710,
#  'fly': 118888,
#  'why': 327893,
#  'waste': 323176,
#  'time': 301031,
#  'about': 19010,
#  'such': 286773,
#  'an': 27421,
#  'thing': 298063,
#  'wouldnt': 331844,
#  'said': 256309,
#  'sometimes': 275840,
#  'believed': 44035,
#  'six': 270788,
#  'things': 298122,
#  'before': 43557,
#  'breakfast': 52581,
#  'memory': 191520,
#  'pained': 221616,
#  'nearby': 204851,
#  'waves': 323708,
#  'impatiently': 154860,
#  'meet': 190863,
#  'under': 312313,
#  'gazebo': 126622,
#  'precisely': 234857,
#  'minutes': 194989,
#  'suddenly': 286879,
#  'two': 309659,
#  'giggling': 128811,
#  'girls': 129321,
#  'appear': 30939,
#  'chattaways': 64733,
#  'faith': 111585,
#  'secret': 261875,
#  'telling': 294121,
#  'much': 201438,
#  'fiona': 116309,
#  'perhaps': 226522,
#  'shouldnt': 267906,
#  'decided': 85337,
#  'should': 267816,
#  'surprised': 288636,
#  'brought': 54006,
#  'fact': 111257,
#  'wonder': 330688,
#  'knows': 171689,
#  'swim': 289694,
#  'naked': 203678,
#  'havershims': 141145,
#  'pond': 232595,
#  'starts': 281984,
#  'walk': 321906,
#  'toward': 304700,
#  'blurts': 49009,
#  'going': 131101,
#  'ask': 33929,
#  'dead': 84661,
#  'sister': 270531,
#  'margaret': 187353,
#  'away': 36974,
#  'ruined': 254710,
#  'surprise': 288630,
#  'strangle': 284683,
#  'went': 325419,
#  'effort': 101058,
#  'theyve': 297872,
#  'come': 71733,
#  'engagement': 104355,
#  'yes': 334810,
#  'want': 322414,
#  'marry': 187884,
#  'better': 45386,
#  'blows': 48704,
#  'nose': 209701,
#  'studies': 285822,
#  'contents': 74696,
#  'kerchief': 169262,
#  'folds': 119282,
#  'pocket': 231667,
#  'youll': 336041,
#  'soon': 276295,
#  'pretty': 235753,
#  'forever': 120200,
#  'end': 104023,
#  'aunt': 36154,
#  'imogene': 154766,
#  'look': 181804,
#  'middleaged': 193318,
#  'overrouged': 219975,
#  'cheeks': 65035,
#  'yellowing': 334671,
#  'burden': 55795,
#  'happy': 139884,
#  'lowell': 182891,
#  'life': 178420,
#  'perfect': 226400,
#  'already': 26100,
#  'ascots': 33654,
#  'looms': 182024,
#  'hers': 144253,
#  'dear': 84894,
#  'shall': 265293,
#  'leisurely': 176823,
#  'stroll': 285461,
#  'jerks': 163783,
#  'quickly': 240715,
#  'rose': 253393,
#  'steers': 282643,
#  'fast': 112504,
#  'clip': 69090,
#  'dreaded': 96052,
#  'decline': 85459,
#  'aristocracy': 32415,
#  'ugly': 310737,
#  'grandchildren': 133029,
#  'lovely': 182748,
#  'bound': 51339,
#  'produce': 236658,
#  'little': 180082,
#  'gasps': 126214,
#  'imbeciles': 154393,
#  'gardeners': 125883,
#  'planted': 230423,
#  'roses': 253477,
#  'specifically': 278036,
#  'asked': 33939,
#  'red': 245168,
#  'paint': 221663,
#  'strangely': 284661,
#  'odd': 212595,
#  'along': 25970,
#  'hurries': 151196,
#  'path': 224065,
#  'hears': 141983,
#  'jingling': 164340,
#  'sound': 276957,
#  'son': 275974,
#  'extremely': 110312,
#  'delicate': 86583,
#  'digestion': 90150,
#  'something': 275735,
#  'large': 174558,
#  'dart': 83564,
#  'nasty': 204268,
#  'enjoy': 104585,
#  'setting': 264419,
#  'dogs': 93407,
#  'dawdle': 84027,
#  'serve': 264162,
#  'wrong': 332348,
#  'foods': 119609,
#  'blockage': 48278,
#  'standing': 281520,
#  'hind': 146152,
#  'staring': 281786,
#  'directly': 90797,
#  'blinks': 48151,
#  'darts': 83591,
#  'behind': 43772,
#  'tree': 306150,
#  '10': 818,
#  'shout': 267946,
#  'pay': 224639,
#  'attention': 35601,
#  'easily': 99427,
#  'saying': 258435,
#  'couldnt': 77134,
#  'more': 199459,
#  'interested': 158389,
#  'excuse': 109123,
#  'dives': 92291,
#  'wooded': 330866,
#  'area': 31971,
#  'moment': 198321,
#  'reeling': 245637,
#  'lands': 174195,
#  'shoulder': 267831,
#  'jumps': 166947,
#  'seeing': 262193,
#  'how': 149758,
#  'very': 318319,
#  'brocade': 53617,
#  'matter': 188781,
#  'cant': 59440,
#  'bothered': 51102,
#  'fancy': 111961,
#  'fiance': 114664,
#  'hes': 144395,
#  'prince': 236086,
#  'alas': 24224,
#  'cannot': 59356,
#  'unless': 313610,
#  'renounces': 247258,
#  'throne': 299803,
#  'isnt': 160577,
#  'tragic': 305278,
#  '11': 1544,
#  'backs': 38635,
#  'runs': 254980,
#  'sisters': 270554,
#  'kissing': 170634,
#  'woman': 330538,
#  'werehattie': 325507,
#  'old': 214631,
#  'friend': 122571,
#  'close': 69299,
#  'bright': 53237,
#  'highly': 145376,
#  'flustered': 118849,
#  'mention': 191768,
#  'confused': 73689,
#  'need': 205235,
#  'trust': 307673,
#  'marriage': 187833,
#  'annoyed': 29149,
#  'told': 302908,
#  'shadows': 265109,
#  'pillars': 228993,
#  'fall': 111702,
#  'prison': 236203,
#  'bars': 40889,
#  'glances': 129735,
#  'string': 285317,
#  'quartet': 240327,
#  'discreetly': 91262,
#  'positioned': 233433,
#  'bows': 51572,
#  'poised': 232009,
#  'drops': 96784,
#  'knee': 171184,
#  'notices': 210068,
#  'artist': 33386,
#  'immortalizing': 154715,
#  '12': 2192,
#  'frantically': 121729,
#  'brushes': 54315,
#  'lets': 177534,
#  'crawl': 78632,
#  'onto': 216185,
#  'finger': 116092,
#  'places': 230133,
#  'gently': 127530,
#  'branch': 52227,
#  'you1l': 335719,
#  'wash': 322972,
#  'motioning': 200293,
#  'below': 44280,
#  'watching': 323319,
#  'question': 240577,
#  'hangs': 139599,
#  'air': 23452,
#  'unsure': 314469,
#  'herself': 144271,
#  'future': 124539,
#  'sanity': 257397,
#  'stammers': 281413,
#  'iite': 153762,
#  'expects': 109603,
#  'toand': 302334,
#  'lordand': 182191,
#  'lastand': 174824,
#  'likebut': 178929,
#  'happening': 139819,
#  'quicklyi': 240724,
#  'thinkii': 298241,
#  'leaning': 176028,
#  'pillar': 228987,
#  'glaring': 129766,
#  'undisguised': 312734,
#  'impatience': 154855,
#  'meadow': 190114,
#  'follows': 119418,
#  'across': 20277,
#  'wait': 321632,
#  'loses': 182331,
#  'sight': 269257,
#  'peeks': 225312,
#  'over': 219517,
#  'hedgerow': 142442,
#  'stumped': 286005,
#  'around': 32862,
#  '13': 2891,
#  'paw': 224584,
#  'reaches': 243817,
#  'grasps': 133260,
#  'ankle': 28923,
#  'quick': 240667,
#  'jerk': 163763,
#  'keeps': 168918,
#  'screaming': 260545,
#  'tumbles': 308429,
#  'heels': 142561,
#  'grabs': 132755,
#  'walls': 322151,
#  'which': 326820,
#  'hung': 150988,
#  'paintings': 221699,
#  'ancient': 27659,
#  'maps': 187137,
#  'cracked': 78243,
#  'mirrors': 195191,
#  'demonic': 86948,
#  'masks': 188281,
#  'etc': 107358,
#  'books': 50445,
#  'jam': 162655,
#  'jars': 163018,
#  'crystal': 80346,
#  'ball': 39575,
#  'badger': 38908,
#  'claw': 68455,
#  'monkeys': 198782,
#  'human': 150664,
#  'skull': 271602,
#  'frantic': 121723,
#  'stop': 284094,
#  'falls': 111758,
#  'begins': 43676,
#  'grow': 134864,
#  'passes': 223808,
#  'still': 283420,
#  'seems': 262266,
#  'hours': 149342,
#  'hall': 138499,
#  'wham': 326065,
#  'hits': 146727,
#  'bottom': 51189,
#  'smacking': 273071,
#  'wooden': 330869,
#  'floor': 118375,
#  'ah': 22712,
#  'wind': 328858,
#  'knocked': 171417,
#  'rubbing': 254467,
#  'bump': 55518,
#  'many': 187037,
#  'doors': 94428,
#  'gets': 128121,
#  'tries': 306702,
#  'locked': 180979,
#  'another': 29285,
#  'knocks': 171451,
#  'hello': 143096,
#  'anyone': 30100,
#  'answer': 29430,
#  'moves': 200763,
#  'every': 108282,
#  'threelegged': 299519,
#  'table': 290802,
#  'small': 273100,
#  'key': 169437,
#  'sitting': 270693,
#  'picks': 228468,
#  'lock': 180964,
#  'few': 114429,
#  'comes': 71808,
#  'upon': 315126,
#  'curtain': 81215,
#  'aside': 33888,
#  'reveal': 249064,
#  'feet': 113566,
#  'high': 145215,
#  'fits': 116972,
#  'opens': 216861,
#  'bends': 44472,
#  'side': 268861,
#  'fountain': 120965,
#  'fit': 116941,
#  'shoulders': 267875,
#  'stuck': 285769,
#  'replaces': 247543,
#  'bottle': 51155,
#  'person': 226851,
#  'put': 239276,
#  'someone': 275650,
#  '14': 3330,
#  'label': 173300,
#  'drink': 96420,
#  'sniffs': 274189,
#  'recoils': 244884,
#  'shrugs': 268337,
#  'shudders': 268421,
#  'gags': 125092,
#  'coughs': 77088,
#  'taste': 292521,
#  'getting': 128152,
#  'larger': 174590,
#  'curious': 81087,
#  'shrinks': 268279,
#  'pov': 234070,
#  'loom': 182016,
#  'above': 19086,
#  'step': 282844,
#  'trips': 306937,
#  'nowoversized': 210609,
#  'clothes': 69561,
#  'dragging': 95795,
#  'open': 216743,
#  'groans': 134476,
#  'realizes': 244129,
#  'done': 93888,
#  'gold': 131179,
#  'keyhole': 169468,
#  'hear': 141918,
#  'voices': 320162,
#  'watch': 323260,
#  '0s': 770,
#  'first': 116665,
#  'dormouse': 94699,
#  'right': 250249,
#  'certain': 63380,
#  'attempts': 35569,
#  'climb': 68992,
#  'leg': 176597,
#  'tangled': 291891,
#  'toobig': 303468,
#  'slides': 272376,
#  'box': 51593,
#  'unseen': 314240,
#  'sort': 276688,
#  'prank': 234598,
#  'amused': 27360,
#  'cake': 58089,
#  'eat': 99526,
#  'written': 332322,
#  'ornate': 217816,
#  'icing': 152629,
#  'considers': 74269,
#  '15': 3723,
#  '16': 4149,
#  '17': 4526,
#  'tiny': 301503,
#  'bite': 47107,
#  'whoosh': 327703,
#  'shoots': 267472,
#  'upward': 315411,
#  'rapidly': 242852,
#  'growing': 134877,
#  'buttons': 56747,
#  'pop': 232883,
#  'seams': 261397,
#  'strained': 284618,
#  'skirt': 271479,
#  'shorter': 267613,
#  'ceiling': 62730,
#  'closerher': 69415,
#  'grazes': 133502,
#  'relieved': 246659,
#  'crouching': 79845,
#  'give': 129496,
#  'swallow': 289217,
#  'shivers': 267141,
#  'steps': 282971,
#  'underland': 312439,
#  'enters': 104985,
#  'fantastical': 112082,
#  'bizarre': 47236,
#  'illogical': 154112,
#  'dangerous': 82995,
#  'absurd': 19305,
#  'brown': 54039,
#  'statues': 282236,
#  'broken': 53738,
#  'overgrown': 219754,
#  'mossy': 200053,
#  'bellowsneezing': 44191,
#  'green': 133730,
#  'pig': 228777,
#  'dashes': 83654,
#  'tall': 291611,
#  'flowers': 118667,
#  'gaunt': 126466,
#  'haunted': 141010,
#  'faces': 111125,
#  'shabby': 265002,
#  'thin': 298052,
#  'birds': 46874,
#  'stalk': 281344,
#  'dragonflies': 95816,
#  'horseflies': 148794,
#  'enormous': 104709,
#  'gnats': 130457,
#  'fierce': 114956,
#  'battle': 41654,
#  'sky': 271647,
#  'curiouser': 81089,
#  'eye': 110448,
#  'glasses': 129817,
#  'walking': 321950,
#  'stick': 283257,
#  'female': 113853,
#  'breeches': 52784,
#  'boys': 51803,
#  'arms': 32671,
#  'thrown': 299931,
#  'each': 98877,
#  'others': 218409,
#  'dee': 85642,
#  'dum': 97612,
#  'stitched': 283722,
#  'collars': 71253,
#  'convinced': 75477,
#  'throws': 299942,
#  'hands': 139355,
#  'gratitude': 133335,
#  'weeks': 324500,
#  'trailing': 305319,
#  'next': 206611,
#  'almost': 25863,
#  'eaten': 99541,
#  'animals': 28808,
#  'entirely': 105082,
#  'unclothed': 312069,
#  'theirshukm': 296581,
#  'public': 238213,
#  'avert': 36723,
#  'talking': 291567,
#  'flower': 118639,
#  'anything': 30147,
#  'because': 42777,
#  'tweedledee': 309231,
#  'might': 193764,
#  'tweedledum': 309232,
#  'aint': 23413,
#  'nohow': 208571,
#  'may': 189132,
#  'shakes': 265235,
#  'speaking': 277911,
#  'tweedleehes': 309233,
#  'contrariwise': 75171,
#  'imtweedledum': 155316,
#  'stweedledee': 286173,
#  'consult': 74489,
#  'absolem': 19243,
#  'exactly': 108752,
#  'arm': 32508,
#  'ill': 153991,
#  'escort': 106798,
#  'being': 43866,
#  'turn': 308785,
#  'tug': 308312,
#  'between': 45477,
#  'leave': 176191,
#  'let': 177451,
#  'family': 111874,
#  'trait': 305393,
#  'tweedles': 309234,
#  'both': 51092,
#  'start': 281911,
#  'humanfaced': 150675,
#  'gossip': 132280,
#  'pass': 223710,
#  'wise': 329579,
#  'absolute': 19251,
#  '18': 4842,
#  'mushroom': 202501,
#  'forest': 120161,
#  'enter': 104952,
#  'mushrooms': 202506,
#  'surrounded': 288712,
#  'mist': 195569,
#  'form': 120353,
#  'ahead': 22797,
#  'rises': 250912,
#  'steady': 282392,
#  'plume': 231379,
#  'coming': 71927,
#  'hookah': 148267,
#  '19': 5199,
#  'smoking': 273633,
#  'iswho': 160899,
#  'smoke': 273568,
#  'rings': 250687,
#  'mean': 190172,
#  'ought': 218647,
#  'stupid': 286074,
#  'girl': 129235,
#  'unroll': 314148,
#  'oraculum': 217243,
#  ...}

# %% [markdown]
# Same procedure as with the BoW, testing the vectorizer as a classfier using different statistical models (logistic regression, random forest and SVC). I will try to implement them with the same hyperparameters as above.
#
# ##### Update:
# - __Logistic Regression__: The regularization parameter C was changed from 0.001 to 0.1, because was too constrained in that it ended up only predicting one of the two labels at every prediction.

# %% [markdown]
# ### TF-IDF Logistic regression

# %%
#initializing logistic regression model again
tf_idf_log_reg = LogisticRegression(
    penalty = 'elasticnet', 
    C = 0.1,  ## CHANGED THIS FROM 0.001 to 0.1 
    random_state=42, 
    solver = 'saga',
    max_iter = 10000,
    l1_ratio = 0.5
    ).fit(tf_idf_features_train, y_train)

# %%
#checking that both labels are predicted
print("Unique predictions in validation set:", np.unique(tf_idf_log_reg.predict(tf_idf_features_val)))
# Out:
# Unique predictions in validation set: [0 1]

# %%
# evaluate model on validation dataset and save performance metrics
model = tf_idf_log_reg
model_name = 'tf_idf_log_reg'

for x, y, nsplit in zip([tf_idf_features_train, tf_idf_features_val, tf_idf_features_test],
                        [y_train, y_val, y_test],
                        ['train', 'val', 'test']):
    mean_accuracy_score = model.score(x, y) 
    preds = model.predict(x)
    f1 = f1_score(y, preds)
    class_report = classification_report(y, preds, output_dict = True)
    roc_auc = roc_auc_score(np.array(y), model.predict_proba(x)[:,1]) # takes the probabiltiy of label = 1 (passing the bechdel-test)
   # roc_curve_calc = roc_curve(np.array(y), clf_log_reg.predict_proba(x)[:,1])#, pos_label = 1)

    # Create a dictionary with metrics for the current split
    metrics = {
        'model': model_name,
        'split': nsplit,
        'mean_acc_score': round(mean_accuracy_score, 4),
        'f1_score': round(f1, 4),
        'cr_label0_precision': class_report['0']['precision'],
        'cr_label0_recall': class_report['0']['recall'],
        'cr_label0_f1_score': class_report['0']['f1-score'],
        'cr_label0_support': class_report['0']['support'],
        'cr_label1_precision': class_report['1']['precision'],
        'cr_label1_recall': class_report['1']['recall'],
        'cr_label1_f1_score': class_report['1']['f1-score'],
        'cr_label1_support': class_report['1']['support'],
        'roc_auc': roc_auc#,
        #'roc_curve': roc_curve_calc
    }
    
    # Convert the dictionary to a DataFrame and concatenate it with the main DataFrame
    performance_df = pd.concat([performance_df, pd.DataFrame([metrics])], ignore_index=True)

# Display the performance metrics
performance_df
# Out:
#              model  split  mean_acc_score  f1_score  cr_label0_precision  \
# 0      BoW_log_reg  train          0.7934    0.7869             0.772487
# 1      BoW_log_reg    val          0.7797    0.7665             0.747475
# 2      BoW_log_reg   test          0.7022    0.6826             0.673267
# 3           BoW_rf  train          0.7786    0.7711             0.757576
# 4           BoW_rf    val          0.7627    0.7439             0.725490
# 5           BoW_rf   test          0.6798    0.6503             0.647619
# 6          BoW_svc  train          0.8096    0.7861             0.750288
# 7          BoW_svc    val          0.7571    0.7152             0.695652
# 8          BoW_svc   test          0.7135    0.6623             0.658120
# 9   tf_idf_log_reg  train          0.6573    0.6860             0.687822
# 10  tf_idf_log_reg    val          0.7175    0.7340             0.743590
# 11  tf_idf_log_reg   test          0.6685    0.6740             0.666667
#
#     cr_label0_recall  cr_label0_f1_score  cr_label0_support  \
# 0           0.828369            0.799452              705.0
# 1           0.840909            0.791444               88.0
# 2           0.772727            0.719577               88.0
# 3           0.815603            0.785519              705.0
# 4           0.840909            0.778947               88.0
# 5           0.772727            0.704663               88.0
# 6           0.924823            0.828463              705.0
# 7           0.909091            0.788177               88.0
# 8           0.875000            0.751220               88.0
# 9           0.568794            0.622671              705.0
# 10          0.659091            0.698795               88.0
# 11          0.659091            0.662857               88.0
#
#     cr_label1_precision  cr_label1_recall  cr_label1_f1_score  \
# 0              0.817221          0.758766            0.786909
# 1              0.820513          0.719101            0.766467
# 2              0.740260          0.633333            0.682635
# 3              0.802731          0.741935            0.771137
# 4              0.813333          0.685393            0.743902
# 5              0.726027          0.588889            0.650307
# 6              0.903461          0.695652            0.786054
# 7              0.870968          0.606742            0.715232
# 8              0.819672          0.555556            0.662252
# 9              0.635928          0.744741            0.686047
# 10             0.696970          0.775281            0.734043
# 11             0.670330          0.677778            0.674033
#
#     cr_label1_support   roc_auc
# 0               713.0  0.866420
# 1                89.0  0.867339
# 2                90.0  0.746338
# 3               713.0  0.866319
# 4                89.0  0.850613
# 5                90.0  0.739899
# 6               713.0  0.919259
# 7                89.0  0.847612
# 8                90.0  0.763510
# 9               713.0  0.726798
# 10               89.0  0.800179
# 11               90.0  0.707955

# %%
# save model performances
#performance_df.to_csv('/work/classes/NLP_exam/3_model_selection/output/performances_df.csv', index = False)
# reload if stopping mid-way
#performance_df = pd.read_csv('/work/classes/NLP_exam/3_model_selection/output/performances_df.csv')

# %% [markdown]
# ### TF-IDF random forest

# %%
# tf-idf random forest
# initializing random forest with the hyperparameters from the randomized search 
tf_idf_forest = RandomForestClassifier(
    n_estimators = 100,
    min_samples_split = 2, 
    max_features = 0.3,
    max_depth = 20, 
    ccp_alpha = 0.01,
    random_state=42).fit(tf_idf_features_train, y_train)

# %%
#checking that both labels are predicted
print("Unique predictions in validation set:", np.unique(tf_idf_forest.predict(tf_idf_features_val)))
# Out:
# Unique predictions in validation set: [0 1]

# %%
model = tf_idf_forest
model_name = 'tf_idf_rf'

for x, y, nsplit in zip([tf_idf_features_train, tf_idf_features_val, tf_idf_features_test],
                        [y_train, y_val, y_test],
                        ['train', 'val', 'test']):
    mean_accuracy_score = model.score(x, y) 
    preds = model.predict(x)
    f1 = f1_score(y, preds)
    class_report = classification_report(y, preds, output_dict = True)
    roc_auc = roc_auc_score(np.array(y), model.predict_proba(x)[:,1]) # takes the probabiltiy of label = 1 (passing the bechdel-test)
    
    # Create a dictionary with metrics for the current split
    metrics = {
        'model': model_name,
        'split': nsplit,
        'mean_acc_score': round(mean_accuracy_score, 4),
        'f1_score': round(f1, 4),
        'cr_label0_precision': class_report['0']['precision'],
        'cr_label0_recall': class_report['0']['recall'],
        'cr_label0_f1_score': class_report['0']['f1-score'],
        'cr_label0_support': class_report['0']['support'],
        'cr_label1_precision': class_report['1']['precision'],
        'cr_label1_recall': class_report['1']['recall'],
        'cr_label1_f1_score': class_report['1']['f1-score'],
        'cr_label1_support': class_report['1']['support'],
        'roc_auc': roc_auc#,
        #'roc_curve': roc_curve_calc
    }
    
    # Convert the dictionary to a DataFrame and concatenate it with the main DataFrame
    performance_df = pd.concat([performance_df, pd.DataFrame([metrics])], ignore_index=True)

# Display the performance metrics
performance_df
# Out:
#              model  split  mean_acc_score  f1_score  cr_label0_precision  \
# 0      BoW_log_reg  train          0.7934    0.7869             0.772487
# 1      BoW_log_reg    val          0.7797    0.7665             0.747475
# 2      BoW_log_reg   test          0.7022    0.6826             0.673267
# 3           BoW_rf  train          0.7786    0.7711             0.757576
# 4           BoW_rf    val          0.7627    0.7439             0.725490
# 5           BoW_rf   test          0.6798    0.6503             0.647619
# 6          BoW_svc  train          0.8096    0.7861             0.750288
# 7          BoW_svc    val          0.7571    0.7152             0.695652
# 8          BoW_svc   test          0.7135    0.6623             0.658120
# 9   tf_idf_log_reg  train          0.6573    0.6860             0.687822
# 10  tf_idf_log_reg    val          0.7175    0.7340             0.743590
# 11  tf_idf_log_reg   test          0.6685    0.6740             0.666667
# 12       tf_idf_rf  train          0.8025    0.7953             0.778506
# 13       tf_idf_rf    val          0.7853    0.7738             0.755102
# 14       tf_idf_rf   test          0.7079    0.6941             0.683673
#
#     cr_label0_recall  cr_label0_f1_score  cr_label0_support  \
# 0           0.828369            0.799452              705.0
# 1           0.840909            0.791444               88.0
# 2           0.772727            0.719577               88.0
# 3           0.815603            0.785519              705.0
# 4           0.840909            0.778947               88.0
# 5           0.772727            0.704663               88.0
# 6           0.924823            0.828463              705.0
# 7           0.909091            0.788177               88.0
# 8           0.875000            0.751220               88.0
# 9           0.568794            0.622671              705.0
# 10          0.659091            0.698795               88.0
# 11          0.659091            0.662857               88.0
# 12          0.842553            0.809264              705.0
# 13          0.840909            0.795699               88.0
# 14          0.761364            0.720430               88.0
#
#     cr_label1_precision  cr_label1_recall  cr_label1_f1_score  \
# 0              0.817221          0.758766            0.786909
# 1              0.820513          0.719101            0.766467
# 2              0.740260          0.633333            0.682635
# 3              0.802731          0.741935            0.771137
# 4              0.813333          0.685393            0.743902
# 5              0.726027          0.588889            0.650307
# 6              0.903461          0.695652            0.786054
# 7              0.870968          0.606742            0.715232
# 8              0.819672          0.555556            0.662252
# 9              0.635928          0.744741            0.686047
# 10             0.696970          0.775281            0.734043
# 11             0.670330          0.677778            0.674033
# 12             0.830534          0.762973            0.795322
# 13             0.822785          0.730337            0.773810
# 14             0.737500          0.655556            0.694118
#
#     cr_label1_support   roc_auc
# 0               713.0  0.866420
# 1                89.0  0.867339
# 2                90.0  0.746338
# 3               713.0  0.866319
# 4                89.0  0.850613
# 5                90.0  0.739899
# 6               713.0  0.919259
# 7                89.0  0.847612
# 8                90.0  0.763510
# 9               713.0  0.726798
# 10               89.0  0.800179
# 11               90.0  0.707955
# 12              713.0  0.907163
# 13               89.0  0.861083
# 14               90.0  0.755429

# %% [markdown]
# ### TF-IDF SVC

# %%
# support vector maching # max_iter=500
tf_idf_svc = SVC(C=0.5, kernel = 'rbf', probability=True, random_state = 42).fit(tf_idf_features_train, y_train)
# C = 1 and kernel = 'rbf' is the default hyperparameters of the SVC

# %%
#checking that both labels are predicted
print("Unique predictions in validation set:", np.unique(tf_idf_svc.predict(tf_idf_features_val)))
# Out:
# Unique predictions in validation set: [0 1]

# %%
#performance_temp = pd.DataFrame()

model = tf_idf_svc
model_name = 'tf_idf_svc'

for x, y, nsplit in zip([tf_idf_features_train, tf_idf_features_val, tf_idf_features_test], 
                        [y_train, y_val, y_test],
                        ['train', 'val', 'test']):
    mean_accuracy_score = model.score(x, y) 
    preds = model.predict(x)
    f1 = f1_score(y, preds)
    class_report = classification_report(y, preds, output_dict = True)

    # Get predicted probabilities for the positive class (class 1)
    y_pred_proba = model.predict_proba(x)[:, 1]  # Probabilities for class 1

    # Compute the ROC AUC score
    roc_auc = roc_auc_score(np.array(y), y_pred_proba)

    #roc_auc = roc_auc_score(np.array(y), clf_svm.predict_proba(x)[:,1]) # takes the probabiltiy of label = 1 (passing the bechdel-test)
   # roc_curve_calc = roc_curve(np.array(y), clf_log_reg.predict_proba(x)[:,1])#, pos_label = 1)

    # Create a dictionary with metrics for the current split
    metrics = {
        'model': model_name,
        'split': nsplit,
        'mean_acc_score': round(mean_accuracy_score, 4),
        'f1_score': round(f1, 4),
        'cr_label0_precision': class_report['0']['precision'],
        'cr_label0_recall': class_report['0']['recall'],
        'cr_label0_f1_score': class_report['0']['f1-score'],
        'cr_label0_support': class_report['0']['support'],
        'cr_label1_precision': class_report['1']['precision'],
        'cr_label1_recall': class_report['1']['recall'],
        'cr_label1_f1_score': class_report['1']['f1-score'],
        'cr_label1_support': class_report['1']['support'],
        'roc_auc': roc_auc#,
        #'roc_curve': roc_curve_calc
    }
    
    # Convert the dictionary to a DataFrame and concatenate it with the main DataFrame
    performance_df = pd.concat([performance_df, pd.DataFrame([metrics])], ignore_index=True)
    #performance_temp = pd.concat([performance_temp, pd.DataFrame([metrics])], ignore_index=True)


# Display the performance metrics
performance_df
# Out:
#              model  split  mean_acc_score  f1_score  cr_label0_precision  \
# 0      BoW_log_reg  train          0.7934    0.7869             0.772487
# 1      BoW_log_reg    val          0.7797    0.7665             0.747475
# 2      BoW_log_reg   test          0.7022    0.6826             0.673267
# 3           BoW_rf  train          0.7786    0.7711             0.757576
# 4           BoW_rf    val          0.7627    0.7439             0.725490
# 5           BoW_rf   test          0.6798    0.6503             0.647619
# 6          BoW_svc  train          0.8096    0.7861             0.750288
# 7          BoW_svc    val          0.7571    0.7152             0.695652
# 8          BoW_svc   test          0.7135    0.6623             0.658120
# 9   tf_idf_log_reg  train          0.6573    0.6860             0.687822
# 10  tf_idf_log_reg    val          0.7175    0.7340             0.743590
# 11  tf_idf_log_reg   test          0.6685    0.6740             0.666667
# 12       tf_idf_rf  train          0.8025    0.7953             0.778506
# 13       tf_idf_rf    val          0.7853    0.7738             0.755102
# 14       tf_idf_rf   test          0.7079    0.6941             0.683673
# 15      tf_idf_svc  train          0.9224    0.9213             0.905866
# 16      tf_idf_svc    val          0.7062    0.7143             0.714286
# 17      tf_idf_svc   test          0.6517    0.6437             0.638298
#
#     cr_label0_recall  cr_label0_f1_score  cr_label0_support  \
# 0           0.828369            0.799452              705.0
# 1           0.840909            0.791444               88.0
# 2           0.772727            0.719577               88.0
# 3           0.815603            0.785519              705.0
# 4           0.840909            0.778947               88.0
# 5           0.772727            0.704663               88.0
# 6           0.924823            0.828463              705.0
# 7           0.909091            0.788177               88.0
# 8           0.875000            0.751220               88.0
# 9           0.568794            0.622671              705.0
# 10          0.659091            0.698795               88.0
# 11          0.659091            0.662857               88.0
# 12          0.842553            0.809264              705.0
# 13          0.840909            0.795699               88.0
# 14          0.761364            0.720430               88.0
# 15          0.941844            0.923505              705.0
# 16          0.681818            0.697674               88.0
# 17          0.681818            0.659341               88.0
#
#     cr_label1_precision  cr_label1_recall  cr_label1_f1_score  \
# 0              0.817221          0.758766            0.786909
# 1              0.820513          0.719101            0.766467
# 2              0.740260          0.633333            0.682635
# 3              0.802731          0.741935            0.771137
# 4              0.813333          0.685393            0.743902
# 5              0.726027          0.588889            0.650307
# 6              0.903461          0.695652            0.786054
# 7              0.870968          0.606742            0.715232
# 8              0.819672          0.555556            0.662252
# 9              0.635928          0.744741            0.686047
# 10             0.696970          0.775281            0.734043
# 11             0.670330          0.677778            0.674033
# 12             0.830534          0.762973            0.795322
# 13             0.822785          0.730337            0.773810
# 14             0.737500          0.655556            0.694118
# 15             0.940146          0.903226            0.921316
# 16             0.698925          0.730337            0.714286
# 17             0.666667          0.622222            0.643678
#
#     cr_label1_support   roc_auc
# 0               713.0  0.866420
# 1                89.0  0.867339
# 2                90.0  0.746338
# 3               713.0  0.866319
# 4                89.0  0.850613
# 5                90.0  0.739899
# 6               713.0  0.919259
# 7                89.0  0.847612
# 8                90.0  0.763510
# 9               713.0  0.726798
# 10               89.0  0.800179
# 11               90.0  0.707955
# 12              713.0  0.907163
# 13               89.0  0.861083
# 14               90.0  0.755429
# 15              713.0  0.971170
# 16               89.0  0.779239
# 17               90.0  0.701831

# %%
# save / reload model
#pkl.dump(tf_idf_svc, file=open(f'/work/classes/NLP_exam/3_model_selection/output/models/tf_idf_svc.pkl', 'wb')) # save the model
#tf_idf_svc = pkl.load(open('/work/classes/NLP_exam/3_model_seleection/output/models/tf_idf_svc.pkl','rb'))

# %%
# save model performances
#performance_df.to_csv('/work/classes/NLP_exam/3_model_selection/output/performances_df.csv', index = False)
# reload if stopping mid-way
#performance_df = pd.read_csv('/work/classes/NLP_exam/3_model_selection/output/performances_df.csv')

# %% [markdown]
# ## Plotting performances of models

# %%
# Specify the order of the legend and the icons
order = ['test', 'val', 'train']
markers = {'test': 's', 'val': 'X', 'train': 'o'}

# Sort the DataFrame by split and f1_score
performance_df['split_order'] = performance_df['split'].map({v: i for i, v in enumerate(order)})  # Map splits to numeric order
performance_df_sorted = performance_df.sort_values(by=['split_order', 'f1_score'], ascending=[True, True])  # Sort by split order and f1_score

# Plot
fig, ax = plt.subplots(figsize=(10, 6))  # Make wider to show all points
sns.scatterplot(data=performance_df_sorted, 
                y='model', 
                x='f1_score', 
                style='split',
                hue='split', 
                markers=markers,
                palette=['darkred', 'darkorange', 'grey'],
                hue_order=order, 
                style_order=order, 
                s=70,
                alpha=0.8)

# Customize plot
plt.title("Performance of Models")
plt.xlabel("F1 Score")
plt.legend(loc='lower right')  # Adjust legend position

# Remove temporary column used for sorting
performance_df.drop(columns='split_order', inplace=True)
#plt.savefig('../figures/model_performance.jpeg', format='jpeg', dpi=300) 
plt.show()

# %% [markdown]
# ## Attempting to evaluate performance by movie decade

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score, classification_report, roc_auc_score
from transformers import AutoTokenizer

# Load data
data = pd.read_csv("../1_data_acquisition/data/labels_and_scripts.csv")

# Create a new column 'decade' by flooring the 'year' to the nearest decade
data['decade'] = (data['year'] // 10) * 10

# Split data into train and test sets (using your existing split)
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Preprocess text data (assuming case-sensitive model)
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
train_texts = train_data["script"].tolist()
train_encodings = tokenizer(train_texts, padding=True, truncation=True)
test_texts = test_data["script"].tolist()
test_encodings = tokenizer(test_texts, padding=True, truncation=True)

# Create TF-IDF features
tfidf_vectorizer = TfidfVectorizer(max_features=10000)
train_tfidf_features = tfidf_vectorizer.fit_transform(train_texts)
test_tfidf_features = tfidf_vectorizer.transform(test_texts)

# Train the TF-IDF Random Forest model on the entire training set
model = RandomForestClassifier(
    n_estimators=100, min_samples_split=2, max_features=0.3, max_depth=20, ccp_alpha=0.01, random_state=42
).fit(train_tfidf_features, train_data["passed_bechdel"])

# Group data by decade
grouped_data = data.groupby('decade')

# Create an empty list to store results
results = []

# Iterate through each decade's data
for decade, decade_data in grouped_data:
  # Preprocess text data for the decade
  decade_texts = decade_data["script"].tolist()
  decade_tfidf_features = tfidf_vectorizer.transform(decade_texts)

  # Make predictions
  y_pred = model.predict(decade_tfidf_features)

  # Calculate metrics
  mean_accuracy = accuracy_score(decade_data["passed_bechdel"], y_pred)
  f1 = f1_score(decade_data["passed_bechdel"], y_pred)
  class_report_ = classification_report(decade_data["passed_bechdel"], y_pred, output_dict=True)
  roc_auc = roc_auc_score(np.array(decade_data["passed_bechdel"]), model.predict_proba(decade_tfidf_features)[:, 1])

  # Store results in a dictionary
  results.append({
      "decade": decade,
      "mean_accuracy": mean_accuracy,
      "f1_score": f1,
      "cr_label0_precision": class_report_["0"]["precision"],
      "cr_label0_recall": class_report_["0"]["recall"],
      "cr_label0_f1_score": class_report_["0"]["f1-score"],
      "cr_label0_support": class_report_["0"]["support"],
      "cr_label1_precision": class_report_["1"]["precision"],
      "cr_label1_recall": class_report_["1"]["recall"],
      "cr_label1_f1_score": class_report_["1"]["f1-score"],
      "cr_label1_support": class_report_["1"]["support"],
      "roc_auc": roc_auc,
  })

# Create a DataFrame from the results
decade_performance_df = pd.DataFrame(results)

# Print or analyze the decade_performance_df
print(decade_performance_df)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/metrics/_ranking.py:375: UndefinedMetricWarning: Only one class is present in y_true. ROC AUC score is not defined in that case.
#   warnings.warn(
#     decade  mean_accuracy  f1_score  cr_label0_precision  cr_label0_recall  \
# 0     1920       0.750000  0.000000             1.000000          0.750000
# 1     1930       0.875000  0.875000             0.875000          0.875000
# 2     1940       0.769231  0.727273             0.666667          1.000000
# 3     1950       0.675000  0.648649             0.681818          0.714286
# 4     1960       0.820513  0.774194             0.909091          0.800000
# 5     1970       0.789474  0.619048             0.854545          0.854545
# 6     1980       0.764103  0.729412             0.737288          0.852941
# 7     1990       0.772595  0.725352             0.743119          0.880435
# 8     2000       0.802128  0.790068             0.779923          0.848739
# 9     2010       0.766727  0.792271             0.681992          0.794643
# 10    2020       0.571429  0.400000             0.600000          0.750000
#
#     cr_label0_f1_score  cr_label0_support  cr_label1_precision  \
# 0             0.857143                8.0             0.000000
# 1             0.875000                8.0             0.875000
# 2             0.800000               12.0             1.000000
# 3             0.697674               21.0             0.666667
# 4             0.851064               25.0             0.705882
# 5             0.854545               55.0             0.619048
# 6             0.790909              102.0             0.805195
# 7             0.805970              184.0             0.824000
# 8             0.812877              238.0             0.829384
# 9             0.734021              224.0             0.842466
# 10            0.666667                4.0             0.500000
#
#     cr_label1_recall  cr_label1_f1_score  cr_label1_support   roc_auc
# 0           0.000000            0.000000                0.0       NaN
# 1           0.875000            0.875000                8.0  0.968750
# 2           0.571429            0.727273               14.0  0.946429
# 3           0.631579            0.648649               19.0  0.776942
# 4           0.857143            0.774194               14.0  0.940000
# 5           0.619048            0.619048               21.0  0.825108
# 6           0.666667            0.729412               93.0  0.862429
# 7           0.647799            0.725352              159.0  0.883135
# 8           0.754310            0.790068              232.0  0.896733
# 9           0.747720            0.792271              329.0  0.881011
# 10          0.333333            0.400000                3.0  0.666667

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report, roc_auc_score

# Load data
data = pd.read_csv("../1_data_acquisition/data/labels_and_scripts.csv")

# Create a new column 'decade' by flooring the 'year' to the nearest decade
data['decade'] = (data['year'] // 10) * 10

# Split data into train and test sets (using your existing split)
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Define the Bag-of-Words (BoW) vectorizer
vectorizer = CountVectorizer(max_features=10000)

# Create BoW features for train and test sets
train_features = vectorizer.fit_transform(train_data["script"])
test_features = vectorizer.transform(test_data["script"])

# Define the logistic regression model
log_reg = LogisticRegression(random_state=42)

# Example parameter grid for Logistic Regression
param_grid = {
    'C': [0.0001, 0.001, 0.01],  # Regularization strength
    'penalty': ['l1', 'l2'],      # Type of regularization
    'solver': ['liblinear', 'saga'],
    'max_iter': [500]
}

# Set up GridSearchCV
grid_search = GridSearchCV(log_reg, param_grid, cv=5, scoring='f1', n_jobs=-1)

# Fit the model to the training data
grid_search.fit(train_features, train_data["passed_bechdel"])

# Print the best hyperparameters and F1 score
print("Best parameters:", grid_search.best_params_)
print("Best F1 score:", grid_search.best_score_)

# Get the best model from GridSearchCV
best_model = grid_search.best_estimator_

# Evaluate the best model on the test set
test_score = best_model.score(test_features, test_data["passed_bechdel"])
print("Test dataset accuracy with best model:", test_score)

# Create an empty list to store results
results = []

# Group data by decade
grouped_data = test_data.groupby('decade')

# Iterate through each decade's data
for decade, decade_data in grouped_data:
  # Get decade's BoW features
  decade_features = vectorizer.transform(decade_data["script"])

  # Make predictions on the decade's data
  y_pred = best_model.predict(decade_features)

  # Calculate metrics
  mean_accuracy = accuracy_score(decade_data["passed_bechdel"], y_pred)
  f1 = f1_score(decade_data["passed_bechdel"], y_pred)
  class_report_ = classification_report(decade_data["passed_bechdel"], y_pred, output_dict=True)
  roc_auc = roc_auc_score(np.array(decade_data["passed_bechdel"]), best_model.predict_proba(decade_features)[:, 1])

  # Store results in a dictionary
  results.append({
      "decade": decade,
      "mean_accuracy": mean_accuracy,
      "f1_score": f1,
      "cr_label0_precision": class_report_["0"]["precision"],
      "cr_label0_recall": class_report_["0"]["recall"],
      "cr_label0_f1_score": class_report_["0"]["f1-score"],
      "cr_label0_support": class_report_["0"]["support"],
      "cr_label1_precision": class_report_["1"]["precision"],
      "cr_label1_recall": class_report_["1"]["recall"],
      "cr_label1_f1_score": class_report_["1"]["f1-score"],
      "cr_label1_support": class_report_["1"]["support"],
      "roc_auc": roc_auc,
  })

# Create a DataFrame from the results
decade_performance_df = pd.DataFrame(results)

# Print or analyze the decade_performance_df
print(decade_performance_df)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Best parameters: {'C': 0.001, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# Best F1 score: 0.7265999149185974
# Test dataset accuracy with best model: 0.6929577464788732
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/ucloud/.local/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#    decade  mean_accuracy  f1_score  cr_label0_precision  cr_label0_recall  \
# 0    1930       0.500000  0.000000             0.500000          1.000000
# 1    1940       0.600000  0.000000             0.600000          1.000000
# 2    1950       0.900000  0.923077             0.750000          1.000000
# 3    1960       0.833333  0.888889             1.000000          0.500000
# 4    1970       0.846154  0.750000             0.800000          1.000000
# 5    1980       0.651163  0.615385             0.640000          0.727273
# 6    1990       0.718310  0.696970             0.666667          0.823529
# 7    2000       0.658824  0.613333             0.611111          0.804878
# 8    2010       0.677966  0.698413             0.600000          0.720000
# 9    2020       1.000000  1.000000             1.000000          1.000000
#
#    cr_label0_f1_score  cr_label0_support  cr_label1_precision  \
# 0            0.666667                1.0             0.000000
# 1            0.750000                3.0             0.000000
# 2            0.857143                3.0             1.000000
# 3            0.666667                2.0             0.800000
# 4            0.888889                8.0             1.000000
# 5            0.680851               22.0             0.666667
# 6            0.736842               34.0             0.793103
# 7            0.694737               41.0             0.741935
# 8            0.654545               50.0             0.758621
# 9            1.000000                1.0             1.000000
#
#    cr_label1_recall  cr_label1_f1_score  cr_label1_support   roc_auc
# 0          0.000000            0.000000                1.0  0.000000
# 1          0.000000            0.000000                2.0  0.500000
# 2          0.857143            0.923077                7.0  1.000000
# 3          1.000000            0.888889                4.0  1.000000
# 4          0.600000            0.750000                5.0  0.700000
# 5          0.571429            0.615385               21.0  0.625541
# 6          0.621622            0.696970               37.0  0.786169
# 7          0.522727            0.613333               44.0  0.789357
# 8          0.647059            0.698413               68.0  0.758235
# 9          1.000000            1.000000                1.0  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# --- Visualization ---

# 1. Accuracy over Decades
plt.figure(figsize=(10, 6))
sns.lineplot(x='decade', y='mean_accuracy', data=decade_performance_df, marker='o')
plt.title('Model Accuracy by Decade')
plt.xlabel('Decade')
plt.ylabel('Accuracy')
plt.grid(True)
plt.show()

# 2. F1-Score over Decades
plt.figure(figsize=(10, 6))
sns.lineplot(x='decade', y='f1_score', data=decade_performance_df, marker='o')
plt.title('Model F1-Score by Decade')
plt.xlabel('Decade')
plt.ylabel('F1-Score')
plt.grid(True)
plt.show()

# --- Class-Specific Performance ---

# 1. Precision for Class 0 (Not Passing Bechdel) over Decades
plt.figure(figsize=(10, 6))
sns.lineplot(x='decade', y='cr_label0_precision', data=decade_performance_df, marker='o')
plt.title('Precision for Class 0 (Not Passing Bechdel) by Decade')
plt.xlabel('Decade')
plt.ylabel('Precision')
plt.grid(True)
plt.show()

# 2. Recall for Class 0 (Not Passing Bechdel) over Decades
plt.figure(figsize=(10, 6))
sns.lineplot(x='decade', y='cr_label0_recall', data=decade_performance_df, marker='o')
plt.title('Recall for Class 0 (Not Passing Bechdel) by Decade')
plt.xlabel('Decade')
plt.ylabel('Recall')
plt.grid(True)
plt.show()

# 3. F1-Score for Class 0 (Not Passing Bechdel) over Decades
plt.figure(figsize=(10, 6))
sns.lineplot(x='decade', y='cr_label0_f1_score', data=decade_performance_df, marker='o')
plt.title('F1-Score for Class 0 (Not Passing Bechdel) by Decade')
plt.xlabel('Decade')
plt.ylabel('F1-Score')
plt.grid(True)
plt.show()

# 4. Precision for Class 1 (Passing Bechdel) over Decades
plt.figure(figsize=(10, 6))
sns.lineplot(x='decade', y='cr_label1_precision', data=decade_performance_df, marker='o')
plt.title('Precision for Class 1 (Passing Bechdel) by Decade')
plt.xlabel('Decade')
plt.ylabel('Precision')
plt.grid(True)
plt.show()

# 5. Recall for Class 1 (Passing Bechdel) over Decades
plt.figure(figsize=(10, 6))
sns.lineplot(x='decade', y='cr_label1_recall', data=decade_performance_df, marker='o')
plt.title('Recall for Class 1 (Passing Bechdel) by Decade')
plt.xlabel('Decade')
plt.ylabel('Recall')
plt.grid(True)
plt.show()

# 6. F1-Score for Class 1 (Passing Bechdel) over Decades
plt.figure(figsize=(10, 6))
sns.lineplot(x='decade', y='cr_label1_f1_score', data=decade_performance_df, marker='o')
plt.title('F1-Score for Class 1 (Passing Bechdel) by Decade')
plt.xlabel('Decade')
plt.ylabel('F1-Score')
plt.grid(True)
plt.show()
