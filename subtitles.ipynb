# %% [markdown]
# # trying open subtitles

# %%
# package 
tesseract # r package - extract text from images

# %%
# load packages
#!pip install pandas 
# !pip install datasets
# !pip install kagglehub
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from datasets import load_dataset

# %%
dataset = load_dataset("open_subtitles", 'en-hi',  trust_remote_code= True)

# %%
dataset['train']['meta']
# Out:
# [{'year': 1948,
#   'imdbId': 40522,
#   'subtitleId': {'en': 4180294, 'hi': 4239106},
#   'sentenceIds': {'en': [1], 'hi': [1]}},
#  {'year': 1948,
#   'imdbId': 40522,
#   'subtitleId': {'en': 4180294, 'hi': 4239106},
#   'sentenceIds': {'en': [2], 'hi': [2]}},
#  {'year': 1948,
#   'imdbId': 40522,
#   'subtitleId': {'en': 4180294, 'hi': 4239106},
#   'sentenceIds': {'en': [3], 'hi': [3]}},
#  {'year': 1948,
#   'imdbId': 40522,
#   'subtitleId': {'en': 4180294, 'hi': 4239106},
#   'sentenceIds': {'en': [4, 5], 'hi': [4]}},
#  {'year': 1948,
#   'imdbId': 40522,
#   'subtitleId': {'en': 4180294, 'hi': 4239106},
#   'sentenceIds': {'en': [6], 'hi': [5, 6]}},
#  {'year': 1948,
#   'imdbId': 40522,
#   'subtitleId': {'en': 4180294, 'hi': 4239106},
#   'sentenceIds': {'en': [7], 'hi': [7]}},
#  {'year': 1948,
#   'imdbId': 40522,
#   'subtitleId': {'en': 4180294, 'hi': 4239106},
#   'sentenceIds': {'en': [8], 'hi': [8]}},
#  {'year': 1948,
#   'imdbId': 40522,
# ...

# %%
dataset['train']['translation']
# Out:
# [{'en': 'THE BICYCLE THIEF', 'hi': 'साइकिल चोर'},
#  {'en': 'Ricci?', 'hi': 'रिच्ची?'},
#  {'en': 'Is Ricci there?', 'hi': 'रिच्ची है क्या?'},
#  {'en': 'Are you deaf? Come on!', 'hi': 'तुम बहरे हो क्या?'},
#  {'en': 'Get a move on.', 'hi': 'उठो! चलो.'},
#  {'en': "And because I'm a bricklayer I should die of hunger?",
#   'hi': 'और क्योंकि मैं राजमिस्त्री हूँ मुझे भूख से मर जाना चाहिए?'},
#  {'en': 'What do you want from me?', 'hi': 'तुम मुझसे क्या चाहते हो?'},
#  {'en': 'Just be patient.', 'hi': 'बस धैर्य रखो.'},
#  {'en': "We'll see what we can do.",
#   'hi': 'हम देखेंगे कि हम क्या कर सकते हैं.'},
#  {'en': "We'll try to find something.", 'hi': 'हम कुछ खोजने की कोशिश करेंगे.'},
#  {'en': "- Ricci, you'll hang posters.", 'hi': '- रिच्ची, तुम पोस्टर लगाओगे.'},
#  {'en': '- Posters?', 'hi': '- पोस्टर?'},
#  {'en': 'Go to the employment office.', 'hi': 'रोजगार कार्यालय जाओ.'},
#  {'en': "They'll give you a work permit.",
#   'hi': 'वे तुम्हें वर्क परमिट दे देंगे.'},
# ...

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("gufukuro/movie-scripts-corpus")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 657M/657M [00:27<00:00, 25.2MB/s]
# Extracting files...
# Path to dataset files: /home/ucloud/.cache/kagglehub/datasets/gufukuro/movie-scripts-corpus/versions/1

# %%
data = "/home/ucloud/.cache/kagglehub/datasets/gufukuro/movie-scripts-corpus/versions/1"

# %%
# !pip install pandas openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import xlrd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 import xlrd
#
# ModuleNotFoundError: No module named 'xlrd'

# %%
# trying to load file from xlsl instead
file_path = "/work/classes/NLP_exam/data/The_Internet_Movie_Script_Dataset.xlsx"
data = pd.read_excel(file_path)
#data = xlrd.open_workbook(file_path)

# %%
data.head()
data.iloc[7,:]
# Out:
# Sr.No                                                      8
# Movie                                                 Cars 2
# Writers                                            Ben Queen
# Genre                             Animation,Action,Adventure
# Date                                               June_2011
# Sript      A sleek British sports car talks directly to u...
# Name: 7, dtype: object

# %%
data.Sript[7]
# Out:
# 'A sleek British sports car talks directly to us in a\n          pixilated, garbled video. He\'s OUT OF BREATH. Crates are\n          visible behind him. We\'re in the shadowy bowels of a steel\n          room.\n                         \n                          LELAND TURBO\n           This is Agent Leland Turbo. I have\n           a flash transmission for Agent Finn\n           McMissile.\n                         \n          SUPERIMPOSE OVER BLACK: WALT DISNEY PICTURES PRESENTS\n                         \n                          LELAND TURBO\n           Finn. My cover\'s been compromised.\n           Everything\'s gone pear-shaped.\n                         \n          SUPERIMPOSE OVER BLACK: A PIXAR ANIMATION STUDIOS FILM\n                         \n                          LELAND TURBO\n           You won\'t believe what I\'ve found\n           out here.\n                         \n          He angles our camera view, reveals a PORTHOLE through which\n          we can see f
# ...
